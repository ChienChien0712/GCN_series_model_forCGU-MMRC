# %%
import argparse
import time
import csv
import pickle
import operator
import datetime
import os

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--dataset', default='sample', help='dataset name: diginetica/yoochoose/sample')
opt = parser.parse_args("")
print(opt)

#set dataset
dataset_url = 'SR-GNN-master/datasets/'
dataset = 'sample_train-item-views.csv'
if opt.dataset == 'diginetica':
    dataset = 'train-item-views.csv'
elif opt.dataset =='yoochoose':
    dataset = 'yoochoose-clicks.dat'
dataset = dataset_url + dataset
print(dataset)
# Out:
# Namespace(dataset='sample')
# SR-GNN-master/datasets/sample_train-item-views.csv

# %%
#load data
with open(dataset, "r") as f:
    if opt.dataset == 'yoochoose':
        reader = csv.DictReader(f, delimiter=',')
    else:
        reader = csv.DictReader(f, delimiter=';')
    sess_clicks = {} #session_id:[item_id,...]
    sess_date = {}
    ctr = 0
    curid = -1
    curdate = None
    #讀取每一行
    for data in reader: 
        sessid = data['session_id']
        #有換sessid才會進入下面if
        if curdate and not curid == sessid:
            date = time.mktime(time.strptime(curdate, '%Y-%m-%d'))
            sess_date[curid] = date
        curid = sessid
        item = data['item_id'], int(data['timeframe'])
        curdate = data['eventdate']
        if sessid in sess_clicks:
            sess_clicks[sessid] += [item]
        else:
            sess_clicks[sessid] = [item]
        ctr += 1
    #sess_clicks: session_id:[(item_id,timeframe),(...,...),(...,...)...]
    #結束讀取每一行了
    date = time.mktime(time.strptime(curdate, '%Y-%m-%d'))
    for i in list(sess_clicks): #i為session_id的迭代
        #依照timeframe由小到大排序
        sorted_clicks = sorted(sess_clicks[i], key=operator.itemgetter(1))
        #選取出item_id(由timeframe小到大排序過後的)
        sess_clicks[i] = [c[0] for c in sorted_clicks]
    sess_date[curid] = date
print("-- Reading data @ %ss" % datetime.datetime.now())
# Out:
# OrderedDict([('session_id', '2'), ('user_id', 'NA'), ('item_id', '3147'), ('timeframe', '883039'), ('eventdate', '2016-05-09')])
# 1
# OrderedDict([('session_id', '4'), ('user_id', 'NA'), ('item_id', '13931'), ('timeframe', '21812'), ('eventdate', '2016-05-09')])
# 2
# OrderedDict([('session_id', '5'), ('user_id', 'NA'), ('item_id', '5140'), ('timeframe', '22430'), ('eventdate', '2016-05-09')])
# 4
# OrderedDict([('session_id', '6'), ('user_id', 'NA'), ('item_id', '73191'), ('timeframe', '53123'), ('eventdate', '2016-05-09')])
# 5
# OrderedDict([('session_id', '7'), ('user_id', 'NA'), ('item_id', '59248'), ('timeframe', '38806'), ('eventdate', '2016-05-09')])
# 6
# OrderedDict([('session_id', '8'), ('user_id', 'NA'), ('item_id', '11542'), ('timeframe', '10067'), ('eventdate', '2016-04-10')])
# 7
# OrderedDict([('session_id', '10'), ('user_id', 'NA'), ('item_id', '69597'), ('timeframe', '193275'), ('eventdate', '2016-04-05')])
# 8
# OrderedDict([('session_id', '12'), ('user_id', 'NA'), ('item_id', '4168'), ('timeframe', '18252'), ('eventdate', '2016-04-05')])
# 10
# OrderedDict([('session_id', '13'), ('user_id', 'NA'), ('item_id', '3680'), ('timeframe', '144850'), ('eventdate', '2016-04-05')])
# 12
# OrderedDict([('session_id', '14'), ('user_id', 'NA'), ('item_id', '36156'), ('timeframe', '24366'), ('eventdate', '2016-04-05')])
# 13
# OrderedDict([('session_id', '15'), ('user_id', 'NA'), ('item_id', '135099'), ('timeframe', '135386'), ('eventdate', '2016-04-05')])
# 14
# OrderedDict([('session_id', '17'), ('user_id', 'NA'), ('item_id', '51353'), ('timeframe', '385045'), ('eventdate', '2016-04-09')])
# 15
# OrderedDict([('session_id', '18'), ('user_id', 'NA'), ('item_id', '38873'), ('timeframe', '163875'), ('eventdate', '2016-04-09')])
# 17
# OrderedDict([('session_id', '20'), ('user_id', 'NA'), ('item_id', '117403'), ('timeframe', '473943'), ('eventdate', '2016-04-03')])
# 18
# OrderedDict([('session_id', '22'), ('user_id', 'NA'), ('item_id', '6542'), ('timeframe', '1068214'), ('eventdate', '2016-04-03')])
# 20
# OrderedDict([('session_id', '24'), ('user_id', 'NA'), ('item_id', '66200'), ('timeframe', '13076'), ('eventdate', '2016-05-10')])
# 22
# OrderedDict([('session_id', '25'), ('user_id', 'NA'), ('item_id', '14895'), ('timeframe', '22946'), ('eventdate', '2016-05-10')])
# 24
# OrderedDict([('session_id', '28'), ('user_id', 'NA'), ('item_id', '1013'), ('timeframe', '610105'), ('eventdate', '2016-05-08')])
# 25
# OrderedDict([('session_id', '29'), ('user_id', 'NA'), ('item_id', '2042'), ('timeframe', '114562'), ('eventdate', '2016-04-04')])
# 28
# OrderedDict([('session_id', '32'), ('user_id', 'NA'), ('item_id', '3719'), ('timeframe', '410142'), ('eventdate', '2016-04-08')])
# 29
# OrderedDict([('session_id', '33'), ('user_id', 'NA'), ('item_id', '32142'), ('timeframe', '65780'), ('eventdate', '2016-04-08')])
# 32
# OrderedDict([('session_id', '34'), ('user_id', 'NA'), ('item_id', '75611'), ('timeframe', '4251'), ('eventdate', '2016-04-08')])
# 33
# OrderedDict([('session_id', '35'), ('user_id', 'NA'), ('item_id', '59968'), ('timeframe', '70766'), ('eventdate', '2016-04-08')])
# 34
# OrderedDict([('session_id', '37'), ('user_id', 'NA'), ('item_id', '8549'), ('timeframe', '177568'), ('eventdate', '2016-04-08')])
# 35
# OrderedDict([('session_id', '38'), ('user_id', 'NA'), ('item_id', '2062'), ('timeframe', '14168'), ('eventdate', '2016-04-08')])
# 37
# OrderedDict([('session_id', '40'), ('user_id', 'NA'), ('item_id', '82984'), ('timeframe', '66531'), ('eventdate', '2016-04-08')])
# 38
# OrderedDict([('session_id', '42'), ('user_id', 'NA'), ('item_id', '4185'), ('timeframe', '152247'), ('eventdate', '2016-04-08')])
# 40
# OrderedDict([('session_id', '43'), ('user_id', 'NA'), ('item_id', '3433'), ('timeframe', '489835'), ('eventdate', '2016-04-09')])
# 42
# OrderedDict([('session_id', '44'), ('user_id', 'NA'), ('item_id', '73655'), ('timeframe', '9251'), ('eventdate', '2016-05-09')])
# 43
# OrderedDict([('session_id', '45'), ('user_id', 'NA'), ('item_id', '6078'), ('timeframe', '989327'), ('eventdate', '2016-05-09')])
# 44
# OrderedDict([('session_id', '46'), ('user_id', 'NA'), ('item_id', '66956'), ('timeframe', '582262'), ('eventdate', '2016-05-09')])
# 45
# OrderedDict([('session_id', '47'), ('user_id', 'NA'), ('item_id', '10741'), ('timeframe', '20517'), ('eventdate', '2016-05-09')])
# 46
# OrderedDict([('session_id', '48'), ('user_id', '2'), ('item_id', '24764'), ('timeframe', '8863'), ('eventdate', '2016-04-09')])
# 47
# OrderedDict([('session_id', '51'), ('user_id', 'NA'), ('item_id', '75611'), ('timeframe', '18600'), ('eventdate', '2016-04-09')])
# 48
# OrderedDict([('session_id', '53'), ('user_id', 'NA'), ('item_id', '6096'), ('timeframe', '975111'), ('eventdate', '2016-04-04')])
# 51
# OrderedDict([('session_id', '54'), ('user_id', 'NA'), ('item_id', '54759'), ('timeframe', '16413'), ('eventdate', '2016-04-04')])
# 53
# OrderedDict([('session_id', '55'), ('user_id', 'NA'), ('item_id', '208138'), ('timeframe', '14093'), ('eventdate', '2016-04-04')])
# 54
# OrderedDict([('session_id', '56'), ('user_id', 'NA'), ('item_id', '20138'), ('timeframe', '250960'), ('eventdate', '2016-05-09')])
# 55
# OrderedDict([('session_id', '57'), ('user_id', 'NA'), ('item_id', '44384'), ('timeframe', '41200'), ('eventdate', '2016-05-09')])
# 56
# OrderedDict([('session_id', '59'), ('user_id', 'NA'), ('item_id', '30893'), ('timeframe', '33305'), ('eventdate', '2016-05-09')])
# 57
# OrderedDict([('session_id', '60'), ('user_id', '3'), ('item_id', '22128'), ('timeframe', '22704'), ('eventdate', '2016-05-09')])
# 59
# OrderedDict([('session_id', '62'), ('user_id', 'NA'), ('item_id', '380235'), ('timeframe', '103055'), ('eventdate', '2016-05-07')])
# 60
# OrderedDict([('session_id', '63'), ('user_id', 'NA'), ('item_id', '14763'), ('timeframe', '67322'), ('eventdate', '2016-05-09')])
# 62
# OrderedDict([('session_id', '64'), ('user_id', 'NA'), ('item_id', '81575'), ('timeframe', '19191'), ('eventdate', '2016-05-09')])
# 63
# OrderedDict([('session_id', '65'), ('user_id', 'NA'), ('item_id', '2809'), ('timeframe', '82609'), ('eventdate', '2016-04-08')])
# 64
# OrderedDict([('session_id', '66'), ('user_id', 'NA'), ('item_id', '49360'), ('timeframe', '13830'), ('eventdate', '2016-04-09')])
# 65
# OrderedDict([('session_id', '67'), ('user_id', 'NA'), ('item_id', '32005'), ('timeframe', '465536'), ('eventdate', '2016-04-09')])
# 66
# OrderedDict([('session_id', '68'), ('user_id', 'NA'), ('item_id', '368353'), ('timeframe', '1061691'), ('eventdate', '2016-04-09')])
# 67
# OrderedDict([('session_id', '70'), ('user_id', 'NA'), ('item_id', '4151'), ('timeframe', '512255'), ('eventdate', '2016-04-09')])
# 68
# OrderedDict([('session_id', '71'), ('user_id', 'NA'), ('item_id', '38073'), ('timeframe', '414953'), ('eventdate', '2016-04-09')])
# 70
# OrderedDict([('session_id', '73'), ('user_id', 'NA'), ('item_id', '84116'), ('timeframe', '9409'), ('eventdate', '2016-05-09')])
# 71
# OrderedDict([('session_id', '75'), ('user_id', 'NA'), ('item_id', '14912'), ('timeframe', '8772'), ('eventdate', '2016-04-08')])
# 73
# OrderedDict([('session_id', '76'), ('user_id', 'NA'), ('item_id', '32902'), ('timeframe', '21869'), ('eventdate', '2016-04-08')])
# 75
# OrderedDict([('session_id', '77'), ('user_id', 'NA'), ('item_id', '30058'), ('timeframe', '624788'), ('eventdate', '2016-04-07')])
# 76
# OrderedDict([('session_id', '79'), ('user_id', 'NA'), ('item_id', '8734'), ('timeframe', '846548'), ('eventdate', '2016-04-07')])
# 77
# OrderedDict([('session_id', '81'), ('user_id', 'NA'), ('item_id', '10858'), ('timeframe', '33419'), ('eventdate', '2016-05-09')])
# 79
# OrderedDict([('session_id', '83'), ('user_id', 'NA'), ('item_id', '15391'), ('timeframe', '9870'), ('eventdate', '2016-04-10')])
# 81
# OrderedDict([('session_id', '84'), ('user_id', 'NA'), ('item_id', '23094'), ('timeframe', '7840'), ('eventdate', '2016-04-08')])
# 83
# OrderedDict([('session_id', '85'), ('user_id', 'NA'), ('item_id', '2442'), ('timeframe', '283790'), ('eventdate', '2016-04-08')])
# 84
# OrderedDict([('session_id', '86'), ('user_id', 'NA'), ('item_id', '31500'), ('timeframe', '18700'), ('eventdate', '2016-04-08')])
# 85
# OrderedDict([('session_id', '87'), ('user_id', 'NA'), ('item_id', '36700'), ('timeframe', '115943'), ('eventdate', '2016-03-22')])
# 86
# OrderedDict([('session_id', '88'), ('user_id', 'NA'), ('item_id', '82691'), ('timeframe', '539332'), ('eventdate', '2016-03-22')])
# 87
# OrderedDict([('session_id', '89'), ('user_id', 'NA'), ('item_id', '3122'), ('timeframe', '41212'), ('eventdate', '2016-03-22')])
# 88
# OrderedDict([('session_id', '90'), ('user_id', 'NA'), ('item_id', '11119'), ('timeframe', '27556'), ('eventdate', '2016-04-08')])
# 89
# OrderedDict([('session_id', '92'), ('user_id', 'NA'), ('item_id', '4787'), ('timeframe', '144502'), ('eventdate', '2016-04-08')])
# 90
# OrderedDict([('session_id', '93'), ('user_id', 'NA'), ('item_id', '25460'), ('timeframe', '763584'), ('eventdate', '2016-04-08')])
# 92
# OrderedDict([('session_id', '94'), ('user_id', 'NA'), ('item_id', '33034'), ('timeframe', '26076'), ('eventdate', '2016-04-08')])
# 93
# OrderedDict([('session_id', '96'), ('user_id', 'NA'), ('item_id', '35311'), ('timeframe', '74613'), ('eventdate', '2016-05-09')])
# 94
# OrderedDict([('session_id', '97'), ('user_id', 'NA'), ('item_id', '14677'), ('timeframe', '17329'), ('eventdate', '2016-05-09')])
# 96
# OrderedDict([('session_id', '99'), ('user_id', 'NA'), ('item_id', '34300'), ('timeframe', '3152'), ('eventdate', '2016-05-09')])
# 97
# OrderedDict([('session_id', '100'), ('user_id', 'NA'), ('item_id', '32342'), ('timeframe', '178714'), ('eventdate', '2016-03-22')])
# 99
# OrderedDict([('session_id', '101'), ('user_id', 'NA'), ('item_id', '25007'), ('timeframe', '50882'), ('eventdate', '2016-04-07')])
# 100
# OrderedDict([('session_id', '102'), ('user_id', 'NA'), ('item_id', '34559'), ('timeframe', '35377'), ('eventdate', '2016-04-08')])
# 101
# OrderedDict([('session_id', '103'), ('user_id', 'NA'), ('item_id', '352'), ('timeframe', '20373'), ('eventdate', '2016-04-08')])
# 102
# OrderedDict([('session_id', '104'), ('user_id', '4'), ('item_id', '10691'), ('timeframe', '271471'), ('eventdate', '2016-03-21')])
# 103
# OrderedDict([('session_id', '105'), ('user_id', 'NA'), ('item_id', '2818'), ('timeframe', '15897'), ('eventdate', '2016-03-21')])
# 104
# OrderedDict([('session_id', '106'), ('user_id', 'NA'), ('item_id', '14312'), ('timeframe', '1152485'), ('eventdate', '2016-03-21')])
# 105
# OrderedDict([('session_id', '108'), ('user_id', 'NA'), ('item_id', '86161'), ('timeframe', '190980'), ('eventdate', '2016-04-09')])
# 106
# OrderedDict([('session_id', '109'), ('user_id', 'NA'), ('item_id', '12233'), ('timeframe', '436402'), ('eventdate', '2016-04-09')])
# 108
# OrderedDict([('session_id', '110'), ('user_id', 'NA'), ('item_id', '81021'), ('timeframe', '178353'), ('eventdate', '2016-04-09')])
# 109
# OrderedDict([('session_id', '112'), ('user_id', 'NA'), ('item_id', '35099'), ('timeframe', '41565'), ('eventdate', '2016-04-09')])
# 110
# OrderedDict([('session_id', '113'), ('user_id', 'NA'), ('item_id', '34053'), ('timeframe', '345533'), ('eventdate', '2016-04-09')])
# 112
# OrderedDict([('session_id', '114'), ('user_id', 'NA'), ('item_id', '180836'), ('timeframe', '7509'), ('eventdate', '2016-03-22')])
# 113
# OrderedDict([('session_id', '115'), ('user_id', 'NA'), ('item_id', '50344'), ('timeframe', '93844'), ('eventdate', '2016-03-22')])
# 114
# OrderedDict([('session_id', '116'), ('user_id', 'NA'), ('item_id', '5560'), ('timeframe', '4031'), ('eventdate', '2016-03-22')])
# 115
# OrderedDict([('session_id', '117'), ('user_id', 'NA'), ('item_id', '7068'), ('timeframe', '29175'), ('eventdate', '2016-03-22')])
# 116
# OrderedDict([('session_id', '118'), ('user_id', 'NA'), ('item_id', '82292'), ('timeframe', '75541'), ('eventdate', '2016-03-22')])
# 117
# OrderedDict([('session_id', '119'), ('user_id', 'NA'), ('item_id', '8917'), ('timeframe', '144566'), ('eventdate', '2016-03-22')])
# 118
# OrderedDict([('session_id', '120'), ('user_id', 'NA'), ('item_id', '12030'), ('timeframe', '630210'), ('eventdate', '2016-05-07')])
# 119
# OrderedDict([('session_id', '122'), ('user_id', 'NA'), ('item_id', '83484'), ('timeframe', '70885'), ('eventdate', '2016-03-22')])
# 120
# OrderedDict([('session_id', '124'), ('user_id', 'NA'), ('item_id', '11945'), ('timeframe', '35588'), ('eventdate', '2016-03-22')])
# 122
# OrderedDict([('session_id', '125'), ('user_id', 'NA'), ('item_id', '3676'), ('timeframe', '272642'), ('eventdate', '2016-03-22')])
# 124
# OrderedDict([('session_id', '126'), ('user_id', 'NA'), ('item_id', '89925'), ('timeframe', '124297'), ('eventdate', '2016-03-22')])
# 125
# OrderedDict([('session_id', '127'), ('user_id', 'NA'), ('item_id', '4124'), ('timeframe', '861990'), ('eventdate', '2016-03-22')])
# 126
# OrderedDict([('session_id', '128'), ('user_id', 'NA'), ('item_id', '83655'), ('timeframe', '219943'), ('eventdate', '2016-03-22')])
# 127
# OrderedDict([('session_id', '129'), ('user_id', '6'), ('item_id', '7837'), ('timeframe', '3966'), ('eventdate', '2016-03-22')])
# 128
# OrderedDict([('session_id', '131'), ('user_id', 'NA'), ('item_id', '265582'), ('timeframe', '592685'), ('eventdate', '2016-05-09')])
# 129
# OrderedDict([('session_id', '132'), ('user_id', 'NA'), ('item_id', '33034'), ('timeframe', '36291'), ('eventdate', '2016-05-06')])
# 131
# OrderedDict([('session_id', '133'), ('user_id', 'NA'), ('item_id', '34605'), ('timeframe', '499215'), ('eventdate', '2016-03-22')])
# 132
# OrderedDict([('session_id', '134'), ('user_id', 'NA'), ('item_id', '7974'), ('timeframe', '9659'), ('eventdate', '2016-03-22')])
# 133
# OrderedDict([('session_id', '137'), ('user_id', 'NA'), ('item_id', '130823'), ('timeframe', '777902'), ('eventdate', '2016-05-06')])
# 134
# OrderedDict([('session_id', '138'), ('user_id', 'NA'), ('item_id', '167930'), ('timeframe', '1019621'), ('eventdate', '2016-05-06')])
# 137
# OrderedDict([('session_id', '139'), ('user_id', 'NA'), ('item_id', '41905'), ('timeframe', '6556'), ('eventdate', '2016-05-06')])
# 138
# OrderedDict([('session_id', '141'), ('user_id', 'NA'), ('item_id', '9737'), ('timeframe', '434156'), ('eventdate', '2016-05-06')])
# 139
# OrderedDict([('session_id', '142'), ('user_id', 'NA'), ('item_id', '1013'), ('timeframe', '12616'), ('eventdate', '2016-05-06')])
# 141
# OrderedDict([('session_id', '143'), ('user_id', 'NA'), ('item_id', '226620'), ('timeframe', '31762'), ('eventdate', '2016-05-06')])
# 142
# OrderedDict([('session_id', '144'), ('user_id', 'NA'), ('item_id', '22715'), ('timeframe', '15815'), ('eventdate', '2016-05-06')])
# 143
# OrderedDict([('session_id', '146'), ('user_id', 'NA'), ('item_id', '2087'), ('timeframe', '418960'), ('eventdate', '2016-05-06')])
# 144
# OrderedDict([('session_id', '147'), ('user_id', 'NA'), ('item_id', '30340'), ('timeframe', '604226'), ('eventdate', '2016-05-06')])
# 146
# OrderedDict([('session_id', '148'), ('user_id', 'NA'), ('item_id', '85849'), ('timeframe', '79105'), ('eventdate', '2016-05-07')])
# 147
# OrderedDict([('session_id', '149'), ('user_id', 'NA'), ('item_id', '7005'), ('timeframe', '211692'), ('eventdate', '2016-05-07')])
# 148
# OrderedDict([('session_id', '150'), ('user_id', 'NA'), ('item_id', '79520'), ('timeframe', '214948'), ('eventdate', '2016-05-06')])
# 149
# OrderedDict([('session_id', '151'), ('user_id', 'NA'), ('item_id', '161528'), ('timeframe', '12334'), ('eventdate', '2016-05-06')])
# 150
# OrderedDict([('session_id', '152'), ('user_id', 'NA'), ('item_id', '24067'), ('timeframe', '455239'), ('eventdate', '2016-05-06')])
# 151
# OrderedDict([('session_id', '153'), ('user_id', 'NA'), ('item_id', '30761'), ('timeframe', '222513'), ('eventdate', '2016-05-06')])
# 152
# OrderedDict([('session_id', '154'), ('user_id', 'NA'), ('item_id', '84626'), ('timeframe', '6660'), ('eventdate', '2016-05-06')])
# 153
# OrderedDict([('session_id', '155'), ('user_id', 'NA'), ('item_id', '9999'), ('timeframe', '25113'), ('eventdate', '2016-05-06')])
# 154
# OrderedDict([('session_id', '156'), ('user_id', '7'), ('item_id', '21638'), ('timeframe', '7784'), ('eventdate', '2016-05-07')])
# 155
# OrderedDict([('session_id', '157'), ('user_id', 'NA'), ('item_id', '11664'), ('timeframe', '99369'), ('eventdate', '2016-05-07')])
# 156
# OrderedDict([('session_id', '158'), ('user_id', 'NA'), ('item_id', '7481'), ('timeframe', '19949'), ('eventdate', '2016-03-23')])
# 157
# OrderedDict([('session_id', '159'), ('user_id', 'NA'), ('item_id', '2253'), ('timeframe', '68199'), ('eventdate', '2016-03-23')])
# 158
# OrderedDict([('session_id', '160'), ('user_id', 'NA'), ('item_id', '114824'), ('timeframe', '264921'), ('eventdate', '2016-03-23')])
# 159
# OrderedDict([('session_id', '161'), ('user_id', 'NA'), ('item_id', '69273'), ('timeframe', '292857'), ('eventdate', '2016-03-23')])
# 160
# OrderedDict([('session_id', '162'), ('user_id', 'NA'), ('item_id', '10713'), ('timeframe', '329802'), ('eventdate', '2016-03-22')])
# 161
# OrderedDict([('session_id', '163'), ('user_id', 'NA'), ('item_id', '40834'), ('timeframe', '119016'), ('eventdate', '2016-03-22')])
# 162
# OrderedDict([('session_id', '164'), ('user_id', 'NA'), ('item_id', '169217'), ('timeframe', '16270'), ('eventdate', '2016-03-22')])
# 163
# OrderedDict([('session_id', '165'), ('user_id', 'NA'), ('item_id', '89710'), ('timeframe', '300621'), ('eventdate', '2016-03-22')])
# 164
# OrderedDict([('session_id', '166'), ('user_id', 'NA'), ('item_id', '378729'), ('timeframe', '8187'), ('eventdate', '2016-05-08')])
# 165
# OrderedDict([('session_id', '167'), ('user_id', 'NA'), ('item_id', '41580'), ('timeframe', '6571'), ('eventdate', '2016-05-08')])
# 166
# OrderedDict([('session_id', '168'), ('user_id', 'NA'), ('item_id', '36266'), ('timeframe', '11181'), ('eventdate', '2016-05-08')])
# 167
# OrderedDict([('session_id', '169'), ('user_id', 'NA'), ('item_id', '6074'), ('timeframe', '8406'), ('eventdate', '2016-03-22')])
# 168
# OrderedDict([('session_id', '170'), ('user_id', '8'), ('item_id', '40988'), ('timeframe', '43970'), ('eventdate', '2016-02-21')])
# 169
# OrderedDict([('session_id', '171'), ('user_id', '9'), ('item_id', '33836'), ('timeframe', '174207'), ('eventdate', '2016-02-21')])
# 170
# OrderedDict([('session_id', '172'), ('user_id', '10'), ('item_id', '10263'), ('timeframe', '108046'), ('eventdate', '2016-02-21')])
# 171
# OrderedDict([('session_id', '173'), ('user_id', '11'), ('item_id', '104616'), ('timeframe', '16657'), ('eventdate', '2016-02-21')])
# 172
# OrderedDict([('session_id', '174'), ('user_id', '12'), ('item_id', '35885'), ('timeframe', '21158'), ('eventdate', '2016-02-21')])
# 173
# OrderedDict([('session_id', '175'), ('user_id', 'NA'), ('item_id', '7095'), ('timeframe', '53620'), ('eventdate', '2016-05-08')])
# 174
# OrderedDict([('session_id', '177'), ('user_id', 'NA'), ('item_id', '4076'), ('timeframe', '13199'), ('eventdate', '2016-05-08')])
# 175
# OrderedDict([('session_id', '178'), ('user_id', 'NA'), ('item_id', '13931'), ('timeframe', '99099'), ('eventdate', '2016-05-09')])
# 177
# OrderedDict([('session_id', '179'), ('user_id', 'NA'), ('item_id', '31233'), ('timeframe', '21134'), ('eventdate', '2016-05-09')])
# 178
# OrderedDict([('session_id', '181'), ('user_id', 'NA'), ('item_id', '8404'), ('timeframe', '61953'), ('eventdate', '2016-03-22')])
# 179
# OrderedDict([('session_id', '182'), ('user_id', 'NA'), ('item_id', '3655'), ('timeframe', '21829'), ('eventdate', '2016-03-22')])
# 181
# OrderedDict([('session_id', '183'), ('user_id', 'NA'), ('item_id', '33890'), ('timeframe', '232351'), ('eventdate', '2016-03-22')])
# 182
# OrderedDict([('session_id', '184'), ('user_id', 'NA'), ('item_id', '33886'), ('timeframe', '13074'), ('eventdate', '2016-05-07')])
# 183
# OrderedDict([('session_id', '185'), ('user_id', 'NA'), ('item_id', '72562'), ('timeframe', '29670'), ('eventdate', '2016-05-07')])
# 184
# OrderedDict([('session_id', '186'), ('user_id', 'NA'), ('item_id', '68815'), ('timeframe', '11962'), ('eventdate', '2016-05-07')])
# 185
# OrderedDict([('session_id', '187'), ('user_id', 'NA'), ('item_id', '13064'), ('timeframe', '608364'), ('eventdate', '2016-05-08')])
# 186
# OrderedDict([('session_id', '188'), ('user_id', 'NA'), ('item_id', '182014'), ('timeframe', '715162'), ('eventdate', '2016-05-08')])
# 187
# OrderedDict([('session_id', '192'), ('user_id', 'NA'), ('item_id', '14758'), ('timeframe', '65350'), ('eventdate', '2016-05-08')])
# 188
# OrderedDict([('session_id', '193'), ('user_id', '13'), ('item_id', '59'), ('timeframe', '60292'), ('eventdate', '2016-01-19')])
# 192
# OrderedDict([('session_id', '194'), ('user_id', 'NA'), ('item_id', '51250'), ('timeframe', '183508'), ('eventdate', '2016-05-08')])
# 193
# OrderedDict([('session_id', '195'), ('user_id', 'NA'), ('item_id', '67926'), ('timeframe', '27191'), ('eventdate', '2016-05-08')])
# 194
# OrderedDict([('session_id', '196'), ('user_id', '14'), ('item_id', '10674'), ('timeframe', '197888'), ('eventdate', '2016-02-05')])
# 195
# OrderedDict([('session_id', '197'), ('user_id', '15'), ('item_id', '33655'), ('timeframe', '35708'), ('eventdate', '2016-02-06')])
# 196
# OrderedDict([('session_id', '198'), ('user_id', 'NA'), ('item_id', '1356'), ('timeframe', '22461'), ('eventdate', '2016-05-25')])
# 197
# OrderedDict([('session_id', '199'), ('user_id', 'NA'), ('item_id', '85571'), ('timeframe', '45383'), ('eventdate', '2016-05-25')])
# 198
# OrderedDict([('session_id', '200'), ('user_id', 'NA'), ('item_id', '16486'), ('timeframe', '108048'), ('eventdate', '2016-05-25')])
# 199
# OrderedDict([('session_id', '201'), ('user_id', 'NA'), ('item_id', '61761'), ('timeframe', '5750'), ('eventdate', '2016-05-08')])
# 200
# OrderedDict([('session_id', '203'), ('user_id', 'NA'), ('item_id', '36271'), ('timeframe', '37001'), ('eventdate', '2016-05-25')])
# 201
# OrderedDict([('session_id', '204'), ('user_id', 'NA'), ('item_id', '81175'), ('timeframe', '10030'), ('eventdate', '2016-05-25')])
# 203
# OrderedDict([('session_id', '205'), ('user_id', 'NA'), ('item_id', '379018'), ('timeframe', '415441'), ('eventdate', '2016-05-25')])
# 204
# OrderedDict([('session_id', '206'), ('user_id', 'NA'), ('item_id', '14851'), ('timeframe', '81151'), ('eventdate', '2016-05-25')])
# 205
# OrderedDict([('session_id', '209'), ('user_id', 'NA'), ('item_id', '38035'), ('timeframe', '177435'), ('eventdate', '2016-05-25')])
# 206
# OrderedDict([('session_id', '210'), ('user_id', 'NA'), ('item_id', '106591'), ('timeframe', '6022'), ('eventdate', '2016-05-25')])
# 209
# OrderedDict([('session_id', '211'), ('user_id', 'NA'), ('item_id', '32082'), ('timeframe', '45121'), ('eventdate', '2016-05-25')])
# 210
# OrderedDict([('session_id', '212'), ('user_id', 'NA'), ('item_id', '379023'), ('timeframe', '10989'), ('eventdate', '2016-05-25')])
# 211
# OrderedDict([('session_id', '213'), ('user_id', 'NA'), ('item_id', '377923'), ('timeframe', '15895'), ('eventdate', '2016-05-25')])
# 212
# OrderedDict([('session_id', '214'), ('user_id', 'NA'), ('item_id', '10237'), ('timeframe', '118021'), ('eventdate', '2016-05-25')])
# 213
# OrderedDict([('session_id', '215'), ('user_id', 'NA'), ('item_id', '36031'), ('timeframe', '156627'), ('eventdate', '2016-05-25')])
# 214
# OrderedDict([('session_id', '216'), ('user_id', 'NA'), ('item_id', '10988'), ('timeframe', '343442'), ('eventdate', '2016-05-25')])
# 215
# OrderedDict([('session_id', '217'), ('user_id', '16'), ('item_id', '72130'), ('timeframe', '610516'), ('eventdate', '2016-02-05')])
# 216
# OrderedDict([('session_id', '219'), ('user_id', '18'), ('item_id', '12319'), ('timeframe', '15650'), ('eventdate', '2016-02-05')])
# 217
# OrderedDict([('session_id', '220'), ('user_id', 'NA'), ('item_id', '11177'), ('timeframe', '7989'), ('eventdate', '2016-05-25')])
# 219
# OrderedDict([('session_id', '222'), ('user_id', 'NA'), ('item_id', '40985'), ('timeframe', '295497'), ('eventdate', '2016-05-08')])
# 220
# OrderedDict([('session_id', '224'), ('user_id', '20'), ('item_id', '13043'), ('timeframe', '295665'), ('eventdate', '2016-02-06')])
# 222
# OrderedDict([('session_id', '227'), ('user_id', '23'), ('item_id', '35981'), ('timeframe', '50240'), ('eventdate', '2016-03-04')])
# 224
# OrderedDict([('session_id', '228'), ('user_id', '24'), ('item_id', '36738'), ('timeframe', '147746'), ('eventdate', '2016-03-04')])
# 227
# OrderedDict([('session_id', '229'), ('user_id', '25'), ('item_id', '5825'), ('timeframe', '31485'), ('eventdate', '2016-03-04')])
# 228
# OrderedDict([('session_id', '230'), ('user_id', '26'), ('item_id', '58998'), ('timeframe', '20011'), ('eventdate', '2016-03-04')])
# 229
# OrderedDict([('session_id', '231'), ('user_id', '27'), ('item_id', '51760'), ('timeframe', '467581'), ('eventdate', '2016-03-04')])
# 230
# OrderedDict([('session_id', '232'), ('user_id', '28'), ('item_id', '74933'), ('timeframe', '24960'), ('eventdate', '2016-03-04')])
# 231
# OrderedDict([('session_id', '233'), ('user_id', '29'), ('item_id', '11017'), ('timeframe', '214750'), ('eventdate', '2016-03-04')])
# 232
# OrderedDict([('session_id', '234'), ('user_id', '30'), ('item_id', '88887'), ('timeframe', '48915'), ('eventdate', '2016-03-04')])
# 233
# OrderedDict([('session_id', '236'), ('user_id', '32'), ('item_id', '95117'), ('timeframe', '881408'), ('eventdate', '2016-02-06')])
# 234
# OrderedDict([('session_id', '238'), ('user_id', 'NA'), ('item_id', '57717'), ('timeframe', '152437'), ('eventdate', '2016-04-25')])
# 236
# OrderedDict([('session_id', '239'), ('user_id', '33'), ('item_id', '10193'), ('timeframe', '526437'), ('eventdate', '2016-02-06')])
# 238
# OrderedDict([('session_id', '240'), ('user_id', 'NA'), ('item_id', '1299'), ('timeframe', '621241'), ('eventdate', '2016-05-09')])
# 239
# OrderedDict([('session_id', '241'), ('user_id', 'NA'), ('item_id', '6848'), ('timeframe', '58383'), ('eventdate', '2016-04-02')])
# 240
# OrderedDict([('session_id', '242'), ('user_id', 'NA'), ('item_id', '78211'), ('timeframe', '138865'), ('eventdate', '2016-05-09')])
# 241
# OrderedDict([('session_id', '244'), ('user_id', 'NA'), ('item_id', '15642'), ('timeframe', '12749'), ('eventdate', '2016-05-09')])
# 242
# OrderedDict([('session_id', '245'), ('user_id', 'NA'), ('item_id', '12319'), ('timeframe', '46063'), ('eventdate', '2016-05-09')])
# 244
# OrderedDict([('session_id', '248'), ('user_id', '35'), ('item_id', '13326'), ('timeframe', '561973'), ('eventdate', '2016-03-04')])
# 245
# OrderedDict([('session_id', '249'), ('user_id', '36'), ('item_id', '50551'), ('timeframe', '127883'), ('eventdate', '2016-03-05')])
# 248
# OrderedDict([('session_id', '250'), ('user_id', '37'), ('item_id', '20748'), ('timeframe', '273066'), ('eventdate', '2016-03-05')])
# 249
# OrderedDict([('session_id', '253'), ('user_id', '40'), ('item_id', '13545'), ('timeframe', '20060'), ('eventdate', '2016-03-05')])
# 250
# OrderedDict([('session_id', '255'), ('user_id', '42'), ('item_id', '645'), ('timeframe', '39932'), ('eventdate', '2016-03-05')])
# 253
# OrderedDict([('session_id', '257'), ('user_id', '44'), ('item_id', '120347'), ('timeframe', '838307'), ('eventdate', '2016-03-04')])
# 255
# OrderedDict([('session_id', '259'), ('user_id', '46'), ('item_id', '79526'), ('timeframe', '2675'), ('eventdate', '2016-02-07')])
# 257
# OrderedDict([('session_id', '260'), ('user_id', '47'), ('item_id', '25274'), ('timeframe', '9510'), ('eventdate', '2016-02-07')])
# 259
# OrderedDict([('session_id', '261'), ('user_id', '48'), ('item_id', '80424'), ('timeframe', '20608'), ('eventdate', '2016-02-07')])
# 260
# OrderedDict([('session_id', '262'), ('user_id', '49'), ('item_id', '39403'), ('timeframe', '39575'), ('eventdate', '2016-02-07')])
# 261
# OrderedDict([('session_id', '263'), ('user_id', '50'), ('item_id', '126879'), ('timeframe', '93716'), ('eventdate', '2016-02-07')])
# 262
# OrderedDict([('session_id', '265'), ('user_id', 'NA'), ('item_id', '30700'), ('timeframe', '382749'), ('eventdate', '2016-05-25')])
# 263
# OrderedDict([('session_id', '269'), ('user_id', '53'), ('item_id', '74476'), ('timeframe', '18633'), ('eventdate', '2016-02-06')])
# 265
# OrderedDict([('session_id', '270'), ('user_id', 'NA'), ('item_id', '30166'), ('timeframe', '283160'), ('eventdate', '2016-05-25')])
# 269
# OrderedDict([('session_id', '271'), ('user_id', 'NA'), ('item_id', '38600'), ('timeframe', '569716'), ('eventdate', '2016-05-25')])
# 270
# OrderedDict([('session_id', '272'), ('user_id', 'NA'), ('item_id', '7468'), ('timeframe', '46710'), ('eventdate', '2016-05-25')])
# 271
# OrderedDict([('session_id', '273'), ('user_id', 'NA'), ('item_id', '1159'), ('timeframe', '99349'), ('eventdate', '2016-05-25')])
# 272
# OrderedDict([('session_id', '275'), ('user_id', 'NA'), ('item_id', '206301'), ('timeframe', '33699'), ('eventdate', '2016-05-05')])
# 273
# OrderedDict([('session_id', '278'), ('user_id', 'NA'), ('item_id', '86550'), ('timeframe', '24010'), ('eventdate', '2016-05-25')])
# 275
# OrderedDict([('session_id', '279'), ('user_id', 'NA'), ('item_id', '34103'), ('timeframe', '364145'), ('eventdate', '2016-05-25')])
# 278
# OrderedDict([('session_id', '281'), ('user_id', '56'), ('item_id', '19441'), ('timeframe', '72309'), ('eventdate', '2016-03-04')])
# 279
# OrderedDict([('session_id', '282'), ('user_id', 'NA'), ('item_id', '32138'), ('timeframe', '432120'), ('eventdate', '2016-04-02')])
# 281
# OrderedDict([('session_id', '283'), ('user_id', 'NA'), ('item_id', '57752'), ('timeframe', '9283'), ('eventdate', '2016-04-02')])
# 282
# OrderedDict([('session_id', '284'), ('user_id', 'NA'), ('item_id', '89940'), ('timeframe', '19361'), ('eventdate', '2016-04-02')])
# 283
# OrderedDict([('session_id', '285'), ('user_id', 'NA'), ('item_id', '66470'), ('timeframe', '325336'), ('eventdate', '2016-04-02')])
# 284
# OrderedDict([('session_id', '287'), ('user_id', 'NA'), ('item_id', '79582'), ('timeframe', '23467'), ('eventdate', '2016-05-26')])
# 285
# OrderedDict([('session_id', '288'), ('user_id', 'NA'), ('item_id', '10122'), ('timeframe', '29676'), ('eventdate', '2016-05-26')])
# 287
# OrderedDict([('session_id', '289'), ('user_id', 'NA'), ('item_id', '125013'), ('timeframe', '18301'), ('eventdate', '2016-05-26')])
# 288
# OrderedDict([('session_id', '290'), ('user_id', 'NA'), ('item_id', '354859'), ('timeframe', '312051'), ('eventdate', '2016-05-26')])
# 289
# OrderedDict([('session_id', '291'), ('user_id', 'NA'), ('item_id', '9338'), ('timeframe', '263119'), ('eventdate', '2016-05-25')])
# 290
# OrderedDict([('session_id', '294'), ('user_id', '57'), ('item_id', '130841'), ('timeframe', '178958'), ('eventdate', '2016-02-06')])
# 291
# OrderedDict([('session_id', '301'), ('user_id', '60'), ('item_id', '10271'), ('timeframe', '38679'), ('eventdate', '2016-03-08')])
# 294
# OrderedDict([('session_id', '302'), ('user_id', 'NA'), ('item_id', '79520'), ('timeframe', '170221'), ('eventdate', '2016-05-26')])
# 301
# OrderedDict([('session_id', '303'), ('user_id', '61'), ('item_id', '4081'), ('timeframe', '22863'), ('eventdate', '2016-02-06')])
# 302
# OrderedDict([('session_id', '305'), ('user_id', '63'), ('item_id', '40156'), ('timeframe', '37325'), ('eventdate', '2016-02-06')])
# 303
# OrderedDict([('session_id', '306'), ('user_id', '64'), ('item_id', '11881'), ('timeframe', '11263'), ('eventdate', '2016-02-07')])
# 305
# OrderedDict([('session_id', '308'), ('user_id', 'NA'), ('item_id', '36035'), ('timeframe', '24018'), ('eventdate', '2016-04-02')])
# 306
# OrderedDict([('session_id', '310'), ('user_id', 'NA'), ('item_id', '19460'), ('timeframe', '17269'), ('eventdate', '2016-04-02')])
# 308
# OrderedDict([('session_id', '312'), ('user_id', 'NA'), ('item_id', '20521'), ('timeframe', '553123'), ('eventdate', '2016-04-25')])
# 310
# OrderedDict([('session_id', '314'), ('user_id', '66'), ('item_id', '31079'), ('timeframe', '489795'), ('eventdate', '2016-02-06')])
# 312
# OrderedDict([('session_id', '315'), ('user_id', '67'), ('item_id', '30839'), ('timeframe', '139847'), ('eventdate', '2016-02-06')])
# 314
# OrderedDict([('session_id', '317'), ('user_id', '69'), ('item_id', '49502'), ('timeframe', '285291'), ('eventdate', '2016-02-06')])
# 315
# OrderedDict([('session_id', '318'), ('user_id', '70'), ('item_id', '134713'), ('timeframe', '10325'), ('eventdate', '2016-02-06')])
# 317
# OrderedDict([('session_id', '319'), ('user_id', '71'), ('item_id', '63142'), ('timeframe', '20442'), ('eventdate', '2016-02-06')])
# 318
# OrderedDict([('session_id', '320'), ('user_id', '72'), ('item_id', '9154'), ('timeframe', '98359'), ('eventdate', '2016-02-06')])
# 319
# OrderedDict([('session_id', '321'), ('user_id', 'NA'), ('item_id', '126082'), ('timeframe', '111719'), ('eventdate', '2016-05-25')])
# 320
# OrderedDict([('session_id', '322'), ('user_id', 'NA'), ('item_id', '30544'), ('timeframe', '88246'), ('eventdate', '2016-05-25')])
# 321
# OrderedDict([('session_id', '323'), ('user_id', 'NA'), ('item_id', '6221'), ('timeframe', '11810'), ('eventdate', '2016-05-25')])
# 322
# OrderedDict([('session_id', '324'), ('user_id', 'NA'), ('item_id', '13044'), ('timeframe', '16459'), ('eventdate', '2016-05-25')])
# 323
# OrderedDict([('session_id', '325'), ('user_id', 'NA'), ('item_id', '12670'), ('timeframe', '174787'), ('eventdate', '2016-05-25')])
# 324
# OrderedDict([('session_id', '326'), ('user_id', 'NA'), ('item_id', '72413'), ('timeframe', '26985'), ('eventdate', '2016-05-25')])
# 325
# OrderedDict([('session_id', '327'), ('user_id', 'NA'), ('item_id', '205009'), ('timeframe', '54314'), ('eventdate', '2016-05-25')])
# 326
# OrderedDict([('session_id', '328'), ('user_id', 'NA'), ('item_id', '8789'), ('timeframe', '64521'), ('eventdate', '2016-05-16')])
# 327
# OrderedDict([('session_id', '329'), ('user_id', '73'), ('item_id', '90107'), ('timeframe', '440385'), ('eventdate', '2016-02-06')])
# 328
# OrderedDict([('session_id', '330'), ('user_id', '74'), ('item_id', '69167'), ('timeframe', '110481'), ('eventdate', '2016-02-05')])
# 329
# OrderedDict([('session_id', '331'), ('user_id', '75'), ('item_id', '52882'), ('timeframe', '154269'), ('eventdate', '2016-02-06')])
# 330
# OrderedDict([('session_id', '332'), ('user_id', '76'), ('item_id', '38128'), ('timeframe', '18024'), ('eventdate', '2016-02-06')])
# 331
# OrderedDict([('session_id', '333'), ('user_id', '77'), ('item_id', '37775'), ('timeframe', '11842'), ('eventdate', '2016-02-06')])
# 332
# OrderedDict([('session_id', '334'), ('user_id', '78'), ('item_id', '72562'), ('timeframe', '18143'), ('eventdate', '2016-02-06')])
# 333
# OrderedDict([('session_id', '335'), ('user_id', '79'), ('item_id', '48167'), ('timeframe', '10252'), ('eventdate', '2016-03-04')])
# 334
# OrderedDict([('session_id', '337'), ('user_id', 'NA'), ('item_id', '11559'), ('timeframe', '150530'), ('eventdate', '2016-04-02')])
# 335
# OrderedDict([('session_id', '338'), ('user_id', 'NA'), ('item_id', '1356'), ('timeframe', '283237'), ('eventdate', '2016-04-02')])
# 337
# OrderedDict([('session_id', '339'), ('user_id', 'NA'), ('item_id', '5413'), ('timeframe', '29056'), ('eventdate', '2016-04-02')])
# 338
# OrderedDict([('session_id', '341'), ('user_id', 'NA'), ('item_id', '37333'), ('timeframe', '547039'), ('eventdate', '2016-04-02')])
# 339
# OrderedDict([('session_id', '342'), ('user_id', 'NA'), ('item_id', '86512'), ('timeframe', '12001'), ('eventdate', '2016-04-02')])
# 341
# OrderedDict([('session_id', '343'), ('user_id', 'NA'), ('item_id', '30165'), ('timeframe', '749789'), ('eventdate', '2016-04-02')])
# 342
# OrderedDict([('session_id', '346'), ('user_id', 'NA'), ('item_id', '12646'), ('timeframe', '640575'), ('eventdate', '2016-05-25')])
# 343
# OrderedDict([('session_id', '347'), ('user_id', 'NA'), ('item_id', '53224'), ('timeframe', '17621'), ('eventdate', '2016-05-25')])
# 346
# OrderedDict([('session_id', '350'), ('user_id', '80'), ('item_id', '80149'), ('timeframe', '8440'), ('eventdate', '2016-05-25')])
# 347
# OrderedDict([('session_id', '353'), ('user_id', 'NA'), ('item_id', '50551'), ('timeframe', '5568'), ('eventdate', '2016-05-25')])
# 350
# OrderedDict([('session_id', '354'), ('user_id', 'NA'), ('item_id', '3314'), ('timeframe', '355057'), ('eventdate', '2016-05-24')])
# 353
# OrderedDict([('session_id', '355'), ('user_id', 'NA'), ('item_id', '379732'), ('timeframe', '142140'), ('eventdate', '2016-05-19')])
# 354
# OrderedDict([('session_id', '356'), ('user_id', '82'), ('item_id', '71942'), ('timeframe', '170475'), ('eventdate', '2016-02-06')])
# 355
# OrderedDict([('session_id', '357'), ('user_id', '83'), ('item_id', '67698'), ('timeframe', '29458'), ('eventdate', '2016-02-06')])
# 356
# OrderedDict([('session_id', '360'), ('user_id', 'NA'), ('item_id', '6249'), ('timeframe', '37874'), ('eventdate', '2016-04-25')])
# 357
# OrderedDict([('session_id', '361'), ('user_id', 'NA'), ('item_id', '34081'), ('timeframe', '41343'), ('eventdate', '2016-04-25')])
# 360
# OrderedDict([('session_id', '362'), ('user_id', 'NA'), ('item_id', '34994'), ('timeframe', '110850'), ('eventdate', '2016-04-25')])
# 361
# OrderedDict([('session_id', '363'), ('user_id', 'NA'), ('item_id', '51257'), ('timeframe', '169534'), ('eventdate', '2016-04-02')])
# 362
# OrderedDict([('session_id', '364'), ('user_id', '86'), ('item_id', '3642'), ('timeframe', '22303'), ('eventdate', '2016-02-21')])
# 363
# OrderedDict([('session_id', '365'), ('user_id', '87'), ('item_id', '882'), ('timeframe', '12862'), ('eventdate', '2016-02-22')])
# 364
# OrderedDict([('session_id', '366'), ('user_id', 'NA'), ('item_id', '76154'), ('timeframe', '249596'), ('eventdate', '2016-04-02')])
# 365
# OrderedDict([('session_id', '367'), ('user_id', 'NA'), ('item_id', '85799'), ('timeframe', '93348'), ('eventdate', '2016-04-02')])
# 366
# OrderedDict([('session_id', '368'), ('user_id', 'NA'), ('item_id', '30110'), ('timeframe', '112872'), ('eventdate', '2016-03-24')])
# 367
# OrderedDict([('session_id', '370'), ('user_id', 'NA'), ('item_id', '169756'), ('timeframe', '533610'), ('eventdate', '2016-04-25')])
# 368
# OrderedDict([('session_id', '371'), ('user_id', 'NA'), ('item_id', '9971'), ('timeframe', '202032'), ('eventdate', '2016-04-25')])
# 370
# OrderedDict([('session_id', '372'), ('user_id', 'NA'), ('item_id', '66806'), ('timeframe', '787530'), ('eventdate', '2016-04-25')])
# 371
# OrderedDict([('session_id', '373'), ('user_id', 'NA'), ('item_id', '6078'), ('timeframe', '21887'), ('eventdate', '2016-04-25')])
# 372
# OrderedDict([('session_id', '374'), ('user_id', 'NA'), ('item_id', '100747'), ('timeframe', '15565'), ('eventdate', '2016-04-25')])
# 373
# OrderedDict([('session_id', '377'), ('user_id', '88'), ('item_id', '12841'), ('timeframe', '42420'), ('eventdate', '2016-02-21')])
# 374
# OrderedDict([('session_id', '378'), ('user_id', '89'), ('item_id', '127250'), ('timeframe', '82926'), ('eventdate', '2016-02-21')])
# 377
# OrderedDict([('session_id', '379'), ('user_id', 'NA'), ('item_id', '32718'), ('timeframe', '26866'), ('eventdate', '2016-04-26')])
# 378
# OrderedDict([('session_id', '380'), ('user_id', 'NA'), ('item_id', '79939'), ('timeframe', '14607'), ('eventdate', '2016-04-26')])
# 379
# OrderedDict([('session_id', '382'), ('user_id', '90'), ('item_id', '32622'), ('timeframe', '21875'), ('eventdate', '2016-02-21')])
# 380
# OrderedDict([('session_id', '383'), ('user_id', '91'), ('item_id', '453456'), ('timeframe', '125931'), ('eventdate', '2016-02-21')])
# 382
# OrderedDict([('session_id', '384'), ('user_id', '92'), ('item_id', '31142'), ('timeframe', '382146'), ('eventdate', '2016-02-21')])
# 383
# OrderedDict([('session_id', '385'), ('user_id', '93'), ('item_id', '49788'), ('timeframe', '151478'), ('eventdate', '2016-02-21')])
# 384
# OrderedDict([('session_id', '389'), ('user_id', 'NA'), ('item_id', '171470'), ('timeframe', '15299'), ('eventdate', '2016-04-25')])
# 385
# OrderedDict([('session_id', '390'), ('user_id', 'NA'), ('item_id', '178151'), ('timeframe', '305653'), ('eventdate', '2016-03-22')])
# 389
# OrderedDict([('session_id', '391'), ('user_id', 'NA'), ('item_id', '60484'), ('timeframe', '321856'), ('eventdate', '2016-04-25')])
# 390
# OrderedDict([('session_id', '392'), ('user_id', 'NA'), ('item_id', '32418'), ('timeframe', '14440'), ('eventdate', '2016-04-25')])
# 391
# OrderedDict([('session_id', '395'), ('user_id', 'NA'), ('item_id', '1356'), ('timeframe', '92055'), ('eventdate', '2016-04-02')])
# 392
# OrderedDict([('session_id', '396'), ('user_id', 'NA'), ('item_id', '25849'), ('timeframe', '333889'), ('eventdate', '2016-04-02')])
# 395
# OrderedDict([('session_id', '397'), ('user_id', 'NA'), ('item_id', '62915'), ('timeframe', '6648'), ('eventdate', '2016-04-02')])
# 396
# OrderedDict([('session_id', '398'), ('user_id', 'NA'), ('item_id', '31638'), ('timeframe', '64178'), ('eventdate', '2016-04-02')])
# 397
# OrderedDict([('session_id', '399'), ('user_id', 'NA'), ('item_id', '606'), ('timeframe', '1097415'), ('eventdate', '2016-03-26')])
# 398
# OrderedDict([('session_id', '401'), ('user_id', 'NA'), ('item_id', '36409'), ('timeframe', '14982'), ('eventdate', '2016-03-26')])
# 399
# OrderedDict([('session_id', '402'), ('user_id', 'NA'), ('item_id', '54017'), ('timeframe', '35888'), ('eventdate', '2016-03-26')])
# 401
# OrderedDict([('session_id', '403'), ('user_id', '94'), ('item_id', '32773'), ('timeframe', '14617'), ('eventdate', '2016-02-13')])
# 402
# OrderedDict([('session_id', '405'), ('user_id', '96'), ('item_id', '55205'), ('timeframe', '10499'), ('eventdate', '2016-02-28')])
# 403
# OrderedDict([('session_id', '407'), ('user_id', '98'), ('item_id', '30151'), ('timeframe', '109463'), ('eventdate', '2016-02-28')])
# 405
# OrderedDict([('session_id', '411'), ('user_id', 'NA'), ('item_id', '83646'), ('timeframe', '432743'), ('eventdate', '2016-04-03')])
# 407
# OrderedDict([('session_id', '413'), ('user_id', 'NA'), ('item_id', '2717'), ('timeframe', '34257'), ('eventdate', '2016-04-03')])
# 411
# OrderedDict([('session_id', '414'), ('user_id', 'NA'), ('item_id', '24511'), ('timeframe', '25206'), ('eventdate', '2016-03-26')])
# 413
# OrderedDict([('session_id', '415'), ('user_id', 'NA'), ('item_id', '36700'), ('timeframe', '73225'), ('eventdate', '2016-03-26')])
# 414
# OrderedDict([('session_id', '416'), ('user_id', 'NA'), ('item_id', '210829'), ('timeframe', '358867'), ('eventdate', '2016-03-26')])
# 415
# OrderedDict([('session_id', '417'), ('user_id', 'NA'), ('item_id', '14444'), ('timeframe', '13639'), ('eventdate', '2016-03-26')])
# 416
# OrderedDict([('session_id', '420'), ('user_id', 'NA'), ('item_id', '30267'), ('timeframe', '451356'), ('eventdate', '2016-03-27')])
# 417
# OrderedDict([('session_id', '421'), ('user_id', 'NA'), ('item_id', '67789'), ('timeframe', '4067'), ('eventdate', '2016-03-27')])
# 420
# OrderedDict([('session_id', '422'), ('user_id', '99'), ('item_id', '34614'), ('timeframe', '19390'), ('eventdate', '2016-02-21')])
# 421
# OrderedDict([('session_id', '423'), ('user_id', '100'), ('item_id', '9617'), ('timeframe', '22453'), ('eventdate', '2016-02-21')])
# 422
# OrderedDict([('session_id', '424'), ('user_id', '101'), ('item_id', '42419'), ('timeframe', '15504'), ('eventdate', '2016-02-21')])
# 423
# OrderedDict([('session_id', '425'), ('user_id', '102'), ('item_id', '33475'), ('timeframe', '20751'), ('eventdate', '2016-02-21')])
# 424
# OrderedDict([('session_id', '426'), ('user_id', '103'), ('item_id', '72846'), ('timeframe', '145643'), ('eventdate', '2016-02-21')])
# 425
# OrderedDict([('session_id', '428'), ('user_id', 'NA'), ('item_id', '103581'), ('timeframe', '7035'), ('eventdate', '2016-04-25')])
# 426
# OrderedDict([('session_id', '429'), ('user_id', '105'), ('item_id', '10850'), ('timeframe', '92486'), ('eventdate', '2016-04-25')])
# 428
# OrderedDict([('session_id', '435'), ('user_id', '109'), ('item_id', '206092'), ('timeframe', '631466'), ('eventdate', '2016-04-02')])
# 429
# OrderedDict([('session_id', '436'), ('user_id', 'NA'), ('item_id', '42779'), ('timeframe', '132807'), ('eventdate', '2016-03-26')])
# 435
# OrderedDict([('session_id', '438'), ('user_id', 'NA'), ('item_id', '92413'), ('timeframe', '79066'), ('eventdate', '2016-03-26')])
# 436
# OrderedDict([('session_id', '439'), ('user_id', 'NA'), ('item_id', '125595'), ('timeframe', '17348'), ('eventdate', '2016-03-27')])
# 438
# OrderedDict([('session_id', '440'), ('user_id', 'NA'), ('item_id', '150027'), ('timeframe', '675516'), ('eventdate', '2016-03-27')])
# 439
# OrderedDict([('session_id', '441'), ('user_id', 'NA'), ('item_id', '19902'), ('timeframe', '677408'), ('eventdate', '2016-03-27')])
# 440
# OrderedDict([('session_id', '443'), ('user_id', '111'), ('item_id', '157728'), ('timeframe', '28877'), ('eventdate', '2016-02-21')])
# 441
# OrderedDict([('session_id', '444'), ('user_id', '112'), ('item_id', '7825'), ('timeframe', '813427'), ('eventdate', '2016-02-21')])
# 443
# OrderedDict([('session_id', '446'), ('user_id', 'NA'), ('item_id', '105612'), ('timeframe', '22036'), ('eventdate', '2016-04-26')])
# 444
# OrderedDict([('session_id', '447'), ('user_id', '160768'), ('item_id', '62915'), ('timeframe', '1158789'), ('eventdate', '2016-02-02')])
# 446
# OrderedDict([('session_id', '449'), ('user_id', 'NA'), ('item_id', '14743'), ('timeframe', '1091076'), ('eventdate', '2016-04-25')])
# 447
# OrderedDict([('session_id', '450'), ('user_id', 'NA'), ('item_id', '10488'), ('timeframe', '13770'), ('eventdate', '2016-04-25')])
# 449
# OrderedDict([('session_id', '451'), ('user_id', '113'), ('item_id', '21856'), ('timeframe', '589736'), ('eventdate', '2016-02-21')])
# 450
# OrderedDict([('session_id', '452'), ('user_id', '114'), ('item_id', '49272'), ('timeframe', '7846'), ('eventdate', '2016-02-21')])
# 451
# OrderedDict([('session_id', '453'), ('user_id', '115'), ('item_id', '32487'), ('timeframe', '21409'), ('eventdate', '2016-02-21')])
# 452
# OrderedDict([('session_id', '454'), ('user_id', 'NA'), ('item_id', '48461'), ('timeframe', '46616'), ('eventdate', '2016-03-26')])
# 453
# OrderedDict([('session_id', '457'), ('user_id', 'NA'), ('item_id', '80547'), ('timeframe', '281470'), ('eventdate', '2016-03-26')])
# 454
# OrderedDict([('session_id', '458'), ('user_id', 'NA'), ('item_id', '22083'), ('timeframe', '928762'), ('eventdate', '2016-03-26')])
# 457
# OrderedDict([('session_id', '459'), ('user_id', 'NA'), ('item_id', '68608'), ('timeframe', '1185906'), ('eventdate', '2016-03-26')])
# 458
# OrderedDict([('session_id', '460'), ('user_id', 'NA'), ('item_id', '10565'), ('timeframe', '6926'), ('eventdate', '2016-03-26')])
# 459
# OrderedDict([('session_id', '461'), ('user_id', 'NA'), ('item_id', '46894'), ('timeframe', '32597'), ('eventdate', '2016-03-26')])
# 460
# OrderedDict([('session_id', '462'), ('user_id', 'NA'), ('item_id', '9600'), ('timeframe', '77806'), ('eventdate', '2016-03-26')])
# 461
# OrderedDict([('session_id', '463'), ('user_id', 'NA'), ('item_id', '908'), ('timeframe', '260199'), ('eventdate', '2016-03-26')])
# 462
# OrderedDict([('session_id', '467'), ('user_id', 'NA'), ('item_id', '13954'), ('timeframe', '50733'), ('eventdate', '2016-03-26')])
# 463
# OrderedDict([('session_id', '469'), ('user_id', 'NA'), ('item_id', '6078'), ('timeframe', '131630'), ('eventdate', '2016-03-26')])
# 467
# OrderedDict([('session_id', '470'), ('user_id', 'NA'), ('item_id', '79421'), ('timeframe', '8103'), ('eventdate', '2016-03-26')])
# 469
# OrderedDict([('session_id', '472'), ('user_id', '116'), ('item_id', '6078'), ('timeframe', '34007'), ('eventdate', '2016-02-22')])
# 470
# OrderedDict([('session_id', '473'), ('user_id', '117'), ('item_id', '3313'), ('timeframe', '6398'), ('eventdate', '2016-02-22')])
# 472
# OrderedDict([('session_id', '474'), ('user_id', '118'), ('item_id', '9667'), ('timeframe', '149546'), ('eventdate', '2016-02-22')])
# 473
# OrderedDict([('session_id', '475'), ('user_id', '119'), ('item_id', '82691'), ('timeframe', '8435'), ('eventdate', '2016-02-22')])
# 474
# OrderedDict([('session_id', '477'), ('user_id', '121'), ('item_id', '16673'), ('timeframe', '13140'), ('eventdate', '2016-02-21')])
# 475
# OrderedDict([('session_id', '478'), ('user_id', '122'), ('item_id', '8240'), ('timeframe', '10659'), ('eventdate', '2016-04-02')])
# 477
# OrderedDict([('session_id', '480'), ('user_id', 'NA'), ('item_id', '70004'), ('timeframe', '582926'), ('eventdate', '2016-04-02')])
# 478
# OrderedDict([('session_id', '484'), ('user_id', 'NA'), ('item_id', '525'), ('timeframe', '64477'), ('eventdate', '2016-04-02')])
# 480
# OrderedDict([('session_id', '485'), ('user_id', '123'), ('item_id', '3751'), ('timeframe', '11163'), ('eventdate', '2016-02-21')])
# 484
# OrderedDict([('session_id', '486'), ('user_id', '124'), ('item_id', '91798'), ('timeframe', '8338'), ('eventdate', '2016-02-21')])
# 485
# OrderedDict([('session_id', '490'), ('user_id', '128'), ('item_id', '227511'), ('timeframe', '157791'), ('eventdate', '2016-02-21')])
# 486
# OrderedDict([('session_id', '492'), ('user_id', '130'), ('item_id', '30837'), ('timeframe', '15588'), ('eventdate', '2016-02-21')])
# 490
# OrderedDict([('session_id', '493'), ('user_id', '131'), ('item_id', '36272'), ('timeframe', '25488'), ('eventdate', '2016-02-28')])
# 492
# ...
# 3839
# OrderedDict([('session_id', '3842'), ('user_id', '1695'), ('item_id', '9126'), ('timeframe', '542860'), ('eventdate', '2016-05-26')])
# 3841
# OrderedDict([('session_id', '3845'), ('user_id', 'NA'), ('item_id', '273677'), ('timeframe', '337753'), ('eventdate', '2016-05-27')])
# 3842
# OrderedDict([('session_id', '3847'), ('user_id', 'NA'), ('item_id', '53120'), ('timeframe', '8566'), ('eventdate', '2016-05-27')])
# 3845
# OrderedDict([('session_id', '3851'), ('user_id', 'NA'), ('item_id', '2673'), ('timeframe', '15067'), ('eventdate', '2016-05-27')])
# 3847
# OrderedDict([('session_id', '3853'), ('user_id', 'NA'), ('item_id', '49272'), ('timeframe', '24533'), ('eventdate', '2016-05-27')])
# 3851
# OrderedDict([('session_id', '3854'), ('user_id', 'NA'), ('item_id', '6450'), ('timeframe', '10945'), ('eventdate', '2016-05-27')])
# 3853
# OrderedDict([('session_id', '3858'), ('user_id', 'NA'), ('item_id', '133119'), ('timeframe', '55727'), ('eventdate', '2016-05-27')])
# 3854
# OrderedDict([('session_id', '3859'), ('user_id', 'NA'), ('item_id', '36031'), ('timeframe', '19996'), ('eventdate', '2016-05-27')])
# 3858
# OrderedDict([('session_id', '3860'), ('user_id', 'NA'), ('item_id', '4172'), ('timeframe', '25315'), ('eventdate', '2016-05-27')])
# 3859
# OrderedDict([('session_id', '3862'), ('user_id', 'NA'), ('item_id', '110877'), ('timeframe', '402147'), ('eventdate', '2016-05-27')])
# 3860
# OrderedDict([('session_id', '3864'), ('user_id', 'NA'), ('item_id', '73298'), ('timeframe', '8172'), ('eventdate', '2016-05-27')])
# 3862
# OrderedDict([('session_id', '3865'), ('user_id', 'NA'), ('item_id', '1047'), ('timeframe', '194866'), ('eventdate', '2016-05-27')])
# 3864
# OrderedDict([('session_id', '3866'), ('user_id', 'NA'), ('item_id', '32259'), ('timeframe', '307766'), ('eventdate', '2016-05-27')])
# 3865
# OrderedDict([('session_id', '3867'), ('user_id', '1697'), ('item_id', '81149'), ('timeframe', '23347'), ('eventdate', '2016-01-24')])
# 3866
# OrderedDict([('session_id', '3868'), ('user_id', '1698'), ('item_id', '180773'), ('timeframe', '9130'), ('eventdate', '2016-01-24')])
# 3867
# OrderedDict([('session_id', '3870'), ('user_id', 'NA'), ('item_id', '581'), ('timeframe', '79087'), ('eventdate', '2016-04-17')])
# 3868
# OrderedDict([('session_id', '3871'), ('user_id', 'NA'), ('item_id', '34843'), ('timeframe', '425091'), ('eventdate', '2016-04-17')])
# 3870
# OrderedDict([('session_id', '3872'), ('user_id', 'NA'), ('item_id', '59965'), ('timeframe', '105459'), ('eventdate', '2016-04-17')])
# 3871
# OrderedDict([('session_id', '3873'), ('user_id', 'NA'), ('item_id', '4877'), ('timeframe', '907372'), ('eventdate', '2016-04-17')])
# 3872
# OrderedDict([('session_id', '3875'), ('user_id', 'NA'), ('item_id', '72281'), ('timeframe', '283130'), ('eventdate', '2016-04-18')])
# 3873
# OrderedDict([('session_id', '3876'), ('user_id', 'NA'), ('item_id', '30626'), ('timeframe', '352917'), ('eventdate', '2016-04-18')])
# 3875
# OrderedDict([('session_id', '3877'), ('user_id', 'NA'), ('item_id', '5582'), ('timeframe', '176579'), ('eventdate', '2016-04-18')])
# 3876
# OrderedDict([('session_id', '3878'), ('user_id', 'NA'), ('item_id', '61613'), ('timeframe', '1160919'), ('eventdate', '2016-04-18')])
# 3877
# OrderedDict([('session_id', '3880'), ('user_id', 'NA'), ('item_id', '54568'), ('timeframe', '233389'), ('eventdate', '2016-04-18')])
# 3878
# OrderedDict([('session_id', '3881'), ('user_id', '1699'), ('item_id', '4632'), ('timeframe', '10724'), ('eventdate', '2016-03-06')])
# 3880
# OrderedDict([('session_id', '3882'), ('user_id', 'NA'), ('item_id', '8047'), ('timeframe', '12032'), ('eventdate', '2016-05-27')])
# 3881
# OrderedDict([('session_id', '3883'), ('user_id', 'NA'), ('item_id', '18621'), ('timeframe', '6942'), ('eventdate', '2016-05-27')])
# 3882
# OrderedDict([('session_id', '3884'), ('user_id', 'NA'), ('item_id', '12917'), ('timeframe', '13494'), ('eventdate', '2016-05-27')])
# 3883
# OrderedDict([('session_id', '3885'), ('user_id', 'NA'), ('item_id', '17466'), ('timeframe', '49144'), ('eventdate', '2016-05-27')])
# 3884
# OrderedDict([('session_id', '3886'), ('user_id', 'NA'), ('item_id', '9600'), ('timeframe', '8419'), ('eventdate', '2016-05-27')])
# 3885
# OrderedDict([('session_id', '3887'), ('user_id', 'NA'), ('item_id', '30504'), ('timeframe', '169659'), ('eventdate', '2016-05-27')])
# 3886
# OrderedDict([('session_id', '3888'), ('user_id', 'NA'), ('item_id', '22926'), ('timeframe', '16714'), ('eventdate', '2016-05-27')])
# 3887
# OrderedDict([('session_id', '3889'), ('user_id', 'NA'), ('item_id', '261'), ('timeframe', '109803'), ('eventdate', '2016-05-27')])
# 3888
# OrderedDict([('session_id', '3890'), ('user_id', 'NA'), ('item_id', '125884'), ('timeframe', '214770'), ('eventdate', '2016-05-27')])
# 3889
# OrderedDict([('session_id', '3891'), ('user_id', 'NA'), ('item_id', '16071'), ('timeframe', '26882'), ('eventdate', '2016-05-27')])
# 3890
# OrderedDict([('session_id', '3893'), ('user_id', 'NA'), ('item_id', '10819'), ('timeframe', '19936'), ('eventdate', '2016-04-28')])
# 3891
# OrderedDict([('session_id', '3894'), ('user_id', 'NA'), ('item_id', '259870'), ('timeframe', '31664'), ('eventdate', '2016-04-28')])
# 3893
# OrderedDict([('session_id', '3895'), ('user_id', 'NA'), ('item_id', '2812'), ('timeframe', '7329'), ('eventdate', '2016-04-28')])
# 3894
# OrderedDict([('session_id', '3896'), ('user_id', 'NA'), ('item_id', '6611'), ('timeframe', '19560'), ('eventdate', '2016-04-28')])
# 3895
# OrderedDict([('session_id', '3897'), ('user_id', 'NA'), ('item_id', '305'), ('timeframe', '12807'), ('eventdate', '2016-04-28')])
# 3896
# OrderedDict([('session_id', '3901'), ('user_id', '1702'), ('item_id', '36182'), ('timeframe', '16737'), ('eventdate', '2016-01-24')])
# 3897
# OrderedDict([('session_id', '3902'), ('user_id', '1703'), ('item_id', '31013'), ('timeframe', '11305'), ('eventdate', '2016-01-24')])
# 3901
# OrderedDict([('session_id', '3903'), ('user_id', '1704'), ('item_id', '160651'), ('timeframe', '7789'), ('eventdate', '2016-01-24')])
# 3902
# OrderedDict([('session_id', '3904'), ('user_id', 'NA'), ('item_id', '68755'), ('timeframe', '39926'), ('eventdate', '2016-04-16')])
# 3903
# OrderedDict([('session_id', '3905'), ('user_id', 'NA'), ('item_id', '51189'), ('timeframe', '674490'), ('eventdate', '2016-04-16')])
# 3904
# OrderedDict([('session_id', '3907'), ('user_id', 'NA'), ('item_id', '12038'), ('timeframe', '132517'), ('eventdate', '2016-04-16')])
# 3905
# OrderedDict([('session_id', '3908'), ('user_id', 'NA'), ('item_id', '40921'), ('timeframe', '15155'), ('eventdate', '2016-04-17')])
# 3907
# OrderedDict([('session_id', '3909'), ('user_id', '1705'), ('item_id', '168668'), ('timeframe', '499039'), ('eventdate', '2016-01-24')])
# 3908
# OrderedDict([('session_id', '3910'), ('user_id', 'NA'), ('item_id', '46491'), ('timeframe', '1088755'), ('eventdate', '2016-05-27')])
# 3909
# OrderedDict([('session_id', '3911'), ('user_id', 'NA'), ('item_id', '10607'), ('timeframe', '10517'), ('eventdate', '2016-05-27')])
# 3910
# OrderedDict([('session_id', '3912'), ('user_id', 'NA'), ('item_id', '666146'), ('timeframe', '371613'), ('eventdate', '2016-05-27')])
# 3911
# OrderedDict([('session_id', '3914'), ('user_id', 'NA'), ('item_id', '136275'), ('timeframe', '691254'), ('eventdate', '2016-05-27')])
# 3912
# OrderedDict([('session_id', '3916'), ('user_id', '1707'), ('item_id', '213621'), ('timeframe', '92100'), ('eventdate', '2016-05-27')])
# 3914
# OrderedDict([('session_id', '3917'), ('user_id', 'NA'), ('item_id', '262'), ('timeframe', '7963'), ('eventdate', '2016-05-27')])
# 3916
# OrderedDict([('session_id', '3918'), ('user_id', 'NA'), ('item_id', '196518'), ('timeframe', '597178'), ('eventdate', '2016-05-27')])
# 3917
# OrderedDict([('session_id', '3919'), ('user_id', 'NA'), ('item_id', '382697'), ('timeframe', '11151'), ('eventdate', '2016-05-27')])
# 3918
# OrderedDict([('session_id', '3920'), ('user_id', '1708'), ('item_id', '8145'), ('timeframe', '26965'), ('eventdate', '2016-01-25')])
# 3919
# OrderedDict([('session_id', '3923'), ('user_id', 'NA'), ('item_id', '164656'), ('timeframe', '17980'), ('eventdate', '2016-05-27')])
# 3920
# OrderedDict([('session_id', '3924'), ('user_id', 'NA'), ('item_id', '20501'), ('timeframe', '47308'), ('eventdate', '2016-05-27')])
# 3923
# OrderedDict([('session_id', '3925'), ('user_id', '1711'), ('item_id', '18101'), ('timeframe', '445800'), ('eventdate', '2016-01-25')])
# 3924
# OrderedDict([('session_id', '3927'), ('user_id', '1713'), ('item_id', '7735'), ('timeframe', '54106'), ('eventdate', '2016-01-25')])
# 3925
# OrderedDict([('session_id', '3929'), ('user_id', '1715'), ('item_id', '25270'), ('timeframe', '17232'), ('eventdate', '2016-01-25')])
# 3927
# OrderedDict([('session_id', '3930'), ('user_id', 'NA'), ('item_id', '4099'), ('timeframe', '6854'), ('eventdate', '2016-04-28')])
# 3929
# OrderedDict([('session_id', '3931'), ('user_id', 'NA'), ('item_id', '9496'), ('timeframe', '964302'), ('eventdate', '2016-04-28')])
# 3930
# OrderedDict([('session_id', '3932'), ('user_id', 'NA'), ('item_id', '31320'), ('timeframe', '1026276'), ('eventdate', '2016-04-19')])
# 3931
# OrderedDict([('session_id', '3934'), ('user_id', '1716'), ('item_id', '24546'), ('timeframe', '38769'), ('eventdate', '2016-02-10')])
# 3932
# OrderedDict([('session_id', '3935'), ('user_id', '1717'), ('item_id', '35338'), ('timeframe', '109681'), ('eventdate', '2016-02-10')])
# 3934
# OrderedDict([('session_id', '3936'), ('user_id', '1718'), ('item_id', '83920'), ('timeframe', '12851'), ('eventdate', '2016-02-10')])
# 3935
# OrderedDict([('session_id', '3938'), ('user_id', '1720'), ('item_id', '58736'), ('timeframe', '13389'), ('eventdate', '2016-02-10')])
# 3936
# OrderedDict([('session_id', '3939'), ('user_id', '1721'), ('item_id', '74532'), ('timeframe', '1134375'), ('eventdate', '2016-01-26')])
# 3938
# OrderedDict([('session_id', '3940'), ('user_id', '1722'), ('item_id', '356749'), ('timeframe', '23789'), ('eventdate', '2016-01-26')])
# 3939
# OrderedDict([('session_id', '3941'), ('user_id', 'NA'), ('item_id', '255869'), ('timeframe', '52701'), ('eventdate', '2016-04-28')])
# 3940
# OrderedDict([('session_id', '3942'), ('user_id', 'NA'), ('item_id', '134626'), ('timeframe', '7456'), ('eventdate', '2016-05-27')])
# 3941
# OrderedDict([('session_id', '3944'), ('user_id', 'NA'), ('item_id', '64097'), ('timeframe', '85699'), ('eventdate', '2016-05-27')])
# 3942
# OrderedDict([('session_id', '3947'), ('user_id', 'NA'), ('item_id', '10607'), ('timeframe', '7424'), ('eventdate', '2016-05-27')])
# 3944
# OrderedDict([('session_id', '3948'), ('user_id', 'NA'), ('item_id', '32138'), ('timeframe', '41894'), ('eventdate', '2016-05-27')])
# 3947
# OrderedDict([('session_id', '3949'), ('user_id', '1723'), ('item_id', '17711'), ('timeframe', '922980'), ('eventdate', '2016-05-27')])
# 3948
# OrderedDict([('session_id', '3950'), ('user_id', 'NA'), ('item_id', '8454'), ('timeframe', '9120'), ('eventdate', '2016-05-27')])
# 3949
# OrderedDict([('session_id', '3951'), ('user_id', 'NA'), ('item_id', '3515'), ('timeframe', '10629'), ('eventdate', '2016-05-27')])
# 3950
# OrderedDict([('session_id', '3953'), ('user_id', '1725'), ('item_id', '13805'), ('timeframe', '76221'), ('eventdate', '2016-01-24')])
# 3951
# OrderedDict([('session_id', '3954'), ('user_id', '1726'), ('item_id', '137550'), ('timeframe', '227890'), ('eventdate', '2016-01-24')])
# 3953
# OrderedDict([('session_id', '3955'), ('user_id', '1727'), ('item_id', '50111'), ('timeframe', '18427'), ('eventdate', '2016-01-24')])
# 3954
# OrderedDict([('session_id', '3957'), ('user_id', '1729'), ('item_id', '3715'), ('timeframe', '32199'), ('eventdate', '2016-01-24')])
# 3955
# OrderedDict([('session_id', '3958'), ('user_id', '1730'), ('item_id', '11352'), ('timeframe', '14607'), ('eventdate', '2016-01-24')])
# 3957
# OrderedDict([('session_id', '3959'), ('user_id', '1731'), ('item_id', '149435'), ('timeframe', '16424'), ('eventdate', '2016-01-24')])
# 3958
# OrderedDict([('session_id', '3960'), ('user_id', '1732'), ('item_id', '8067'), ('timeframe', '9516'), ('eventdate', '2016-04-17')])
# 3959
# OrderedDict([('session_id', '3962'), ('user_id', 'NA'), ('item_id', '118408'), ('timeframe', '119874'), ('eventdate', '2016-04-17')])
# 3960
# OrderedDict([('session_id', '3963'), ('user_id', '1733'), ('item_id', '35390'), ('timeframe', '8785'), ('eventdate', '2016-01-24')])
# 3962
# OrderedDict([('session_id', '3964'), ('user_id', 'NA'), ('item_id', '9617'), ('timeframe', '26350'), ('eventdate', '2016-04-18')])
# 3963
# OrderedDict([('session_id', '3965'), ('user_id', 'NA'), ('item_id', '1356'), ('timeframe', '97547'), ('eventdate', '2016-04-18')])
# 3964
# OrderedDict([('session_id', '3966'), ('user_id', '1734'), ('item_id', '3633'), ('timeframe', '7960'), ('eventdate', '2016-01-25')])
# 3965
# OrderedDict([('session_id', '3967'), ('user_id', '1735'), ('item_id', '91685'), ('timeframe', '156781'), ('eventdate', '2016-01-25')])
# 3966
# OrderedDict([('session_id', '3968'), ('user_id', '1736'), ('item_id', '18315'), ('timeframe', '19010'), ('eventdate', '2016-01-25')])
# 3967
# OrderedDict([('session_id', '3969'), ('user_id', 'NA'), ('item_id', '12723'), ('timeframe', '271195'), ('eventdate', '2016-04-27')])
# 3968
# OrderedDict([('session_id', '3972'), ('user_id', 'NA'), ('item_id', '30892'), ('timeframe', '218717'), ('eventdate', '2016-04-28')])
# 3969
# OrderedDict([('session_id', '3973'), ('user_id', 'NA'), ('item_id', '36956'), ('timeframe', '30499'), ('eventdate', '2016-04-28')])
# 3972
# OrderedDict([('session_id', '3975'), ('user_id', '1738'), ('item_id', '35859'), ('timeframe', '22166'), ('eventdate', '2016-01-24')])
# 3973
# OrderedDict([('session_id', '3976'), ('user_id', '1739'), ('item_id', '60637'), ('timeframe', '19457'), ('eventdate', '2016-01-24')])
# 3975
# OrderedDict([('session_id', '3977'), ('user_id', '1740'), ('item_id', '41603'), ('timeframe', '19941'), ('eventdate', '2016-01-24')])
# 3976
# OrderedDict([('session_id', '3978'), ('user_id', '1741'), ('item_id', '52744'), ('timeframe', '55007'), ('eventdate', '2016-01-24')])
# 3977
# OrderedDict([('session_id', '3979'), ('user_id', '1742'), ('item_id', '34653'), ('timeframe', '110657'), ('eventdate', '2016-01-24')])
# 3978
# OrderedDict([('session_id', '3980'), ('user_id', '1743'), ('item_id', '150234'), ('timeframe', '119648'), ('eventdate', '2016-01-24')])
# 3979
# OrderedDict([('session_id', '3981'), ('user_id', 'NA'), ('item_id', '33696'), ('timeframe', '178074'), ('eventdate', '2016-03-18')])
# 3980
# OrderedDict([('session_id', '3982'), ('user_id', 'NA'), ('item_id', '6488'), ('timeframe', '5198'), ('eventdate', '2016-03-18')])
# 3981
# OrderedDict([('session_id', '3984'), ('user_id', 'NA'), ('item_id', '1211'), ('timeframe', '85818'), ('eventdate', '2016-03-18')])
# 3982
# OrderedDict([('session_id', '3989'), ('user_id', 'NA'), ('item_id', '1706'), ('timeframe', '110712'), ('eventdate', '2016-04-28')])
# 3984
# OrderedDict([('session_id', '3990'), ('user_id', '1747'), ('item_id', '190975'), ('timeframe', '157805'), ('eventdate', '2016-01-24')])
# 3989
# OrderedDict([('session_id', '3991'), ('user_id', 'NA'), ('item_id', '6571'), ('timeframe', '7640'), ('eventdate', '2016-04-28')])
# 3990
# OrderedDict([('session_id', '3993'), ('user_id', 'NA'), ('item_id', '25043'), ('timeframe', '9259'), ('eventdate', '2016-04-28')])
# 3991
# OrderedDict([('session_id', '3994'), ('user_id', 'NA'), ('item_id', '85241'), ('timeframe', '32780'), ('eventdate', '2016-04-28')])
# 3993
# OrderedDict([('session_id', '3995'), ('user_id', 'NA'), ('item_id', '29167'), ('timeframe', '61860'), ('eventdate', '2016-04-28')])
# 3994
# OrderedDict([('session_id', '3996'), ('user_id', 'NA'), ('item_id', '26897'), ('timeframe', '9068'), ('eventdate', '2016-04-17')])
# 3995
# OrderedDict([('session_id', '3997'), ('user_id', 'NA'), ('item_id', '5352'), ('timeframe', '10260'), ('eventdate', '2016-04-17')])
# 3996
# OrderedDict([('session_id', '3998'), ('user_id', 'NA'), ('item_id', '81762'), ('timeframe', '169241'), ('eventdate', '2016-04-17')])
# 3997
# OrderedDict([('session_id', '3999'), ('user_id', 'NA'), ('item_id', '198848'), ('timeframe', '13834'), ('eventdate', '2016-04-17')])
# 3998
# -- Reading data @ 2021-05-24 18:23:32.441967s

# %%
# Filter out length 1 sessions
# 刪除只有一個sess_clicks的資料
for s in list(sess_clicks):
    if len(sess_clicks[s]) == 1:
        del sess_clicks[s]
        del sess_date[s]
# Count number of times each item appears
# item_id出現的次數
iid_counts = {}
for s in sess_clicks:
    seq = sess_clicks[s]
    for iid in seq:
        if iid in iid_counts:
            iid_counts[iid] += 1
        else:
            iid_counts[iid] = 1
# item_id 出現次數的排序，由小到大
sorted_counts = sorted(iid_counts.items(), key=operator.itemgetter(1))

length = len(sess_clicks)
for s in list(sess_clicks):
    curseq = sess_clicks[s]
    #filseq: 只總出現次數>=5次的item_id
    filseq = list(filter(lambda i: iid_counts[i] >= 5, curseq))
    #如果此session下少於2個item_id出現，就刪除。
    if len(filseq) < 2:
        del sess_clicks[s]
        del sess_date[s]
    else:
        sess_clicks[s] = filseq
        
# Split out test set based on dates
# 先找到最新的時間點(秒數)
dates = list(sess_date.items())
maxdate = dates[0][1]
for _, date in dates:
    if maxdate < date:
        maxdate = date

# 7 days for test
# 最近七天的資料當作testing set
# 七天之前的資料都是training set
splitdate = maxdate - 86400 * 7
print('Splitting date', splitdate)      # Yoochoose: ('Split date', 1411930799.0)
tra_sess = filter(lambda x: x[1] < splitdate, dates) # (session_id, date)
tes_sess = filter(lambda x: x[1] > splitdate, dates) # (session_id, date)

# Sort sessions by date
# testing set、training set依照時間序排列，由小到大
tra_sess = sorted(tra_sess, key=operator.itemgetter(1))     # [(session_id, timestamp), (), ]
tes_sess = sorted(tes_sess, key=operator.itemgetter(1))     # [(session_id, timestamp), (), ]
print('# training set:',len(tra_sess))    # 186670    # 7966257
print('# testing set:',len(tes_sess))    # 15979     # 15324
print('training set: %s, ...'%str(tra_sess[:3])[1:-1])
print('testing set: %s, ...'%str(tes_sess[:3])[1:-1])
print("-- Splitting train set and test set @ %ss" % datetime.datetime.now())
# Out:
# Splitting date 1464105600.0
# # training set: 372
# # testing set: 38
# training set: ('2671', 1451923200.0), ('3780', 1452355200.0), ('1213', 1452441600.0), ...
# testing set: ('1864', 1464192000.0), ('1867', 1464192000.0), ('1868', 1464192000.0), ...
# -- Splitting train set and test set @ 2021-05-24 19:27:08.009557s

# %%
tra_sess
# Out:
# [('2671', 1451923200.0),
#  ('3780', 1452355200.0),
#  ('1213', 1452441600.0),
#  ('1479', 1452528000.0),
#  ('1190', 1452787200.0),
#  ('2707', 1452787200.0),
#  ('498', 1453046400.0),
#  ('537', 1453046400.0),
#  ('2340', 1453132800.0),
#  ('2341', 1453132800.0),
#  ('794', 1453219200.0),
#  ('884', 1453219200.0),
#  ('3435', 1453305600.0),
#  ('1135', 1453478400.0),
#  ('1170', 1453564800.0),
#  ('1189', 1453564800.0),
#  ('3909', 1453564800.0),
#  ('3957', 1453564800.0),
#  ('3925', 1453651200.0),
#  ('3283', 1453737600.0),
#  ('3484', 1453824000.0),
#  ('3532', 1453824000.0),
#  ('3548', 1453824000.0),
#  ('1537', 1453910400.0),
#  ('1518', 1453996800.0),
#  ('1526', 1454083200.0),
#  ('1769', 1454083200.0),
#  ('1791', 1454083200.0),
#  ('1845', 1454083200.0),
#  ('2525', 1454083200.0),
#  ('2461', 1454169600.0),
#  ('2586', 1454169600.0),
#  ('2615', 1454169600.0),
#  ('2472', 1454342400.0),
#  ('1564', 1454515200.0),
#  ('224', 1454688000.0),
#  ('236', 1454688000.0),
#  ('239', 1454688000.0),
#  ('320', 1454688000.0),
#  ('329', 1454688000.0),
#  ('259', 1454774400.0),
#  ('3609', 1454860800.0),
#  ('972', 1454947200.0),
#  ('976', 1454947200.0),
#  ('977', 1454947200.0),
#  ('961', 1455033600.0),
#  ('2332', 1455120000.0),
#  ('2402', 1455120000.0),
#  ('2432', 1455120000.0),
#  ('852', 1455206400.0),
#  ('869', 1455206400.0),
#  ('2318', 1455206400.0),
#  ('1259', 1455292800.0),
#  ('1280', 1455292800.0),
#  ('534', 1455379200.0),
#  ('694', 1455379200.0),
#  ('697', 1455379200.0),
#  ('2563', 1455379200.0),
#  ('2575', 1455379200.0),
#  ('723', 1455465600.0),
#  ('726', 1455465600.0),
#  ('747', 1455465600.0),
#  ('756', 1455465600.0),
#  ('770', 1455465600.0),
#  ('775', 1455465600.0),
#  ('1514', 1455552000.0),
#  ('1201', 1455638400.0),
#  ('1226', 1455638400.0),
#  ('1228', 1455638400.0),
#  ('3468', 1455724800.0),
#  ('3483', 1455724800.0),
#  ('3538', 1455811200.0),
#  ('3539', 1455811200.0),
#  ('3540', 1455811200.0),
#  ('172', 1455984000.0),
#  ('423', 1455984000.0),
#  ('452', 1455984000.0),
#  ('365', 1456070400.0),
#  ('472', 1456070400.0),
#  ('473', 1456070400.0),
#  ('474', 1456070400.0),
#  ('475', 1456070400.0),
#  ('1432', 1456156800.0),
#  ('1437', 1456156800.0),
#  ('1467', 1456156800.0),
#  ('1488', 1456156800.0),
#  ('3077', 1456243200.0),
#  ('3093', 1456243200.0),
#  ('3102', 1456243200.0),
#  ('3104', 1456243200.0),
#  ('3147', 1456243200.0),
#  ('3269', 1456243200.0),
#  ('908', 1456329600.0),
#  ('913', 1456329600.0),
#  ('2163', 1456329600.0),
#  ('2206', 1456329600.0),
#  ('3190', 1456329600.0),
#  ('2998', 1456416000.0),
#  ('3034', 1456416000.0),
#  ('1877', 1456502400.0),
#  ('1888', 1456502400.0),
#  ('1926', 1456502400.0),
#  ('1928', 1456502400.0),
#  ('1936', 1456502400.0),
#  ('545', 1456588800.0),
#  ('548', 1456588800.0),
#  ('557', 1456588800.0),
#  ('497', 1456675200.0),
#  ('1394', 1456761600.0),
#  ('2859', 1456761600.0),
#  ('3370', 1456761600.0),
#  ('3543', 1456761600.0),
#  ('1652', 1456848000.0),
#  ('1701', 1456848000.0),
#  ('2359', 1456934400.0),
#  ('232', 1457020800.0),
#  ('248', 1457020800.0),
#  ('1286', 1457020800.0),
#  ('2320', 1457020800.0),
#  ('2322', 1457020800.0),
#  ('301', 1457366400.0),
#  ('2298', 1457366400.0),
#  ('2688', 1457452800.0),
#  ('2780', 1457452800.0),
#  ('1419', 1457539200.0),
#  ('1427', 1457539200.0),
#  ('1438', 1457539200.0),
#  ('1446', 1457539200.0),
#  ('1503', 1457539200.0),
#  ('1507', 1457539200.0),
#  ('2496', 1457625600.0),
#  ('2533', 1457625600.0),
#  ('2537', 1457625600.0),
#  ('2541', 1457625600.0),
#  ('1313', 1457712000.0),
#  ('1349', 1457712000.0),
#  ('2504', 1457712000.0),
#  ('2593', 1457712000.0),
#  ('1380', 1457798400.0),
#  ('1383', 1457798400.0),
#  ('2558', 1457884800.0),
#  ('2610', 1457884800.0),
#  ('1650', 1457971200.0),
#  ('1673', 1457971200.0),
#  ('1691', 1457971200.0),
#  ('1720', 1457971200.0),
#  ('2050', 1458057600.0),
#  ('2051', 1458057600.0),
#  ('1160', 1458144000.0),
#  ('1196', 1458144000.0),
#  ('2016', 1458144000.0),
#  ('1120', 1458230400.0),
#  ('3224', 1458230400.0),
#  ('3286', 1458230400.0),
#  ('3302', 1458230400.0),
#  ('3303', 1458230400.0),
#  ('3317', 1458230400.0),
#  ('3319', 1458230400.0),
#  ('3320', 1458230400.0),
#  ('3348', 1458230400.0),
#  ('628', 1458403200.0),
#  ('629', 1458403200.0),
#  ('630', 1458403200.0),
#  ('3243', 1458403200.0),
#  ('3244', 1458403200.0),
#  ('3245', 1458403200.0),
#  ('104', 1458489600.0),
#  ('106', 1458489600.0),
#  ('625', 1458489600.0),
#  ('712', 1458489600.0),
#  ('713', 1458489600.0),
#  ('88', 1458576000.0),
#  ('125', 1458576000.0),
#  ('128', 1458576000.0),
#  ('162', 1458576000.0),
#  ('169', 1458576000.0),
#  ('672', 1458576000.0),
#  ('3051', 1458748800.0),
#  ('3082', 1458748800.0),
#  ('3084', 1458748800.0),
#  ('3119', 1458748800.0),
#  ('1556', 1458835200.0),
#  ('1622', 1458835200.0),
#  ('1628', 1458835200.0),
#  ('3183', 1458835200.0),
#  ('3185', 1458835200.0),
#  ('505', 1458921600.0),
#  ('526', 1458921600.0),
#  ('420', 1459008000.0),
#  ('441', 1459008000.0),
#  ('1492', 1459008000.0),
#  ('1493', 1459008000.0),
#  ('3001', 1459180800.0),
#  ('3003', 1459180800.0),
#  ('2411', 1459267200.0),
#  ('2899', 1459267200.0),
#  ('2900', 1459267200.0),
#  ('2901', 1459267200.0),
#  ('2902', 1459267200.0),
#  ('2907', 1459267200.0),
#  ('2910', 1459267200.0),
#  ('2912', 1459267200.0),
#  ('2921', 1459267200.0),
#  ('2932', 1459267200.0),
#  ('2947', 1459267200.0),
#  ('2951', 1459267200.0),
#  ('2970', 1459267200.0),
#  ('2975', 1459267200.0),
#  ('1285', 1459353600.0),
#  ('1343', 1459353600.0),
#  ('1326', 1459440000.0),
#  ('3176', 1459440000.0),
#  ('3210', 1459440000.0),
#  ('3213', 1459440000.0),
#  ('3230', 1459440000.0),
#  ('3235', 1459440000.0),
#  ('282', 1459526400.0),
#  ('285', 1459526400.0),
#  ('338', 1459526400.0),
#  ('339', 1459526400.0),
#  ('341', 1459526400.0),
#  ('395', 1459526400.0),
#  ('411', 1459612800.0),
#  ('413', 1459612800.0),
#  ('2798', 1459612800.0),
#  ('2799', 1459612800.0),
#  ('2802', 1459612800.0),
#  ('2863', 1459612800.0),
#  ('2864', 1459612800.0),
#  ('2880', 1459612800.0),
#  ('2885', 1459612800.0),
#  ('2840', 1459699200.0),
#  ('2962', 1459699200.0),
#  ('2965', 1459699200.0),
#  ('3688', 1459785600.0),
#  ('3690', 1459785600.0),
#  ('3719', 1459785600.0),
#  ('3721', 1459785600.0),
#  ('3770', 1459785600.0),
#  ('3773', 1459785600.0),
#  ('2356', 1459872000.0),
#  ('2368', 1459872000.0),
#  ('2380', 1459872000.0),
#  ('2416', 1459872000.0),
#  ('2448', 1459872000.0),
#  ('2451', 1459872000.0),
#  ('2371', 1459958400.0),
#  ('32', 1460044800.0),
#  ('37', 1460044800.0),
#  ('40', 1460044800.0),
#  ('42', 1460044800.0),
#  ('48', 1460131200.0),
#  ('68', 1460131200.0),
#  ('108', 1460131200.0),
#  ('109', 1460131200.0),
#  ('2134', 1460217600.0),
#  ('2243', 1460217600.0),
#  ('2254', 1460217600.0),
#  ('2287', 1460217600.0),
#  ('3716', 1460217600.0),
#  ('1024', 1460304000.0),
#  ('1027', 1460304000.0),
#  ('1041', 1460304000.0),
#  ('1051', 1460304000.0),
#  ('1054', 1460304000.0),
#  ('2306', 1460304000.0),
#  ('2310', 1460304000.0),
#  ('2527', 1460390400.0),
#  ('2559', 1460390400.0),
#  ('2656', 1460390400.0),
#  ('1355', 1460476800.0),
#  ('2566', 1460476800.0),
#  ('2790', 1460476800.0),
#  ('2823', 1460476800.0),
#  ('2876', 1460476800.0),
#  ('2877', 1460476800.0),
#  ('2108', 1460563200.0),
#  ('2120', 1460563200.0),
#  ('2125', 1460563200.0),
#  ('2128', 1460563200.0),
#  ('2129', 1460563200.0),
#  ('2136', 1460563200.0),
#  ('2150', 1460563200.0),
#  ('2151', 1460563200.0),
#  ('2237', 1460563200.0),
#  ('2733', 1460563200.0),
#  ('3021', 1460563200.0),
#  ('2146', 1460649600.0),
#  ('3139', 1460649600.0),
#  ('3170', 1460649600.0),
#  ('2049', 1460736000.0),
#  ('2069', 1460736000.0),
#  ('2070', 1460736000.0),
#  ('2075', 1460736000.0),
#  ('2076', 1460736000.0),
#  ('3097', 1460736000.0),
#  ('3112', 1460736000.0),
#  ('3905', 1460736000.0),
#  ('2098', 1460822400.0),
#  ('3513', 1460822400.0),
#  ('1455', 1460908800.0),
#  ('1457', 1460908800.0),
#  ('2007', 1460908800.0),
#  ('2011', 1460908800.0),
#  ('3876', 1460908800.0),
#  ('3877', 1460908800.0),
#  ('3964', 1460908800.0),
#  ('3965', 1460908800.0),
#  ('1916', 1460995200.0),
#  ('1002', 1461081600.0),
#  ('1096', 1461081600.0),
#  ('362', 1461513600.0),
#  ('371', 1461513600.0),
#  ('373', 1461513600.0),
#  ('391', 1461513600.0),
#  ('392', 1461513600.0),
#  ('1638', 1461513600.0),
#  ('1640', 1461513600.0),
#  ('2557', 1461600000.0),
#  ('1813', 1461686400.0),
#  ('1814', 1461686400.0),
#  ('1939', 1461686400.0),
#  ('3969', 1461686400.0),
#  ('1847', 1461772800.0),
#  ('1850', 1461772800.0),
#  ('3972', 1461772800.0),
#  ('3973', 1461772800.0),
#  ('3995', 1461772800.0),
#  ('1094', 1461945600.0),
#  ('1119', 1461945600.0),
#  ('1139', 1461945600.0),
#  ('1763', 1462032000.0),
#  ('1780', 1462032000.0),
#  ('1817', 1462032000.0),
#  ('1781', 1462118400.0),
#  ('586', 1462204800.0),
#  ('1954', 1462377600.0),
#  ('147', 1462464000.0),
#  ('1974', 1462464000.0),
#  ('2004', 1462464000.0),
#  ('149', 1462550400.0),
#  ('187', 1462636800.0),
#  ('942', 1462636800.0),
#  ('3449', 1462636800.0),
#  ('2', 1462723200.0),
#  ('5', 1462723200.0),
#  ('7', 1462723200.0),
#  ('96', 1462723200.0),
#  ('178', 1462723200.0),
#  ('242', 1462723200.0),
#  ('739', 1462809600.0),
#  ('1826', 1462809600.0),
#  ('951', 1462982400.0),
#  ('955', 1462982400.0),
#  ('2276', 1462982400.0),
#  ('2278', 1462982400.0),
#  ('3663', 1462982400.0),
#  ('2390', 1463760000.0),
#  ('2392', 1463760000.0),
#  ('3332', 1463760000.0),
#  ('3344', 1463760000.0),
#  ('3750', 1463846400.0),
#  ('3767', 1463846400.0),
#  ('3805', 1463846400.0),
#  ('3816', 1463846400.0),
#  ('3817', 1463846400.0),
#  ('2696', 1464019200.0),
#  ('2721', 1464019200.0),
#  ('2740', 1464019200.0),
#  ('2741', 1464019200.0),
#  ('2752', 1464019200.0),
#  ('2754', 1464019200.0)]

# %%
# Choosing item count >=5 gives approximately the same number of items as reported in paper
item_dict = {} #item_id:new_index
# Convert training sessions to sequences and renumber items to start from 1
def obtian_tra():
    train_ids = []
    train_seqs = []
    train_dates = []
    item_ctr = 1 #item_ctr: item_id的new_index編號
    for s, date in tra_sess:
        #seq: 不同session_id(s)下的sequence(seq)
        seq = sess_clicks[s]
        outseq = []
        #i: item_id
        for i in seq:
            #如果已存在item_id:new_index
            if i in item_dict:
                outseq += [item_dict[i]]
            #若不存在，則建立新的item_id:new_index於item_dict[i]
            else:
                outseq += [item_ctr]
                item_dict[i] = item_ctr
                item_ctr += 1
        #前面已經處理過使得outseq一定不會<2，但為了保險所以再次判斷
        if len(outseq) < 2:  
            continue
        train_ids += [s]
        train_dates += [date]
        train_seqs += [outseq]
    print('total number of items:',item_ctr)    
    return train_ids, train_dates, train_seqs

# Convert test sessions to sequences, ignoring items that do not appear in training set
def obtian_tes():
    test_ids = []
    test_seqs = []
    test_dates = []
    for s, date in tes_sess:
        seq = sess_clicks[s]
        outseq = []
        for i in seq:
            #在testing set當中出現的item_id是要在training set中也出現過的。
            if i in item_dict:
                outseq += [item_dict[i]]
        if len(outseq) < 2:
            continue
        test_ids += [s]
        test_dates += [date]
        test_seqs += [outseq]
    return test_ids, test_dates, test_seqs

#execute
tra_ids, tra_dates, tra_seqs = obtian_tra()
tes_ids, tes_dates, tes_seqs = obtian_tes()
# Out:
# total #items: 221

# %%
def process_seqs(iseqs, idates):
    out_seqs = []
    out_dates = []
    labs = []
    ids = []
    for id, seq, date in zip(range(len(iseqs)), iseqs, idates):
        #print(seq)
        for i in range(1, len(seq)):
            #print(-i)
            tar = seq[-i]
            labs += [tar]
            out_seqs += [seq[:-i]]
            #print('tar',tar)
            #print('labs',labs)
            #print(out_seqs)
            out_dates += [date]
            ids += [id]
    return out_seqs, out_dates, labs, ids


tr_seqs, tr_dates, tr_labs, tr_ids = process_seqs(tra_seqs, tra_dates)
te_seqs, te_dates, te_labs, te_ids = process_seqs(tes_seqs, tes_dates)
tra = (tr_seqs, tr_labs)
tes = (te_seqs, te_labs)
print('number of training set:', len(tr_seqs))
print('number of testing set:', len(te_seqs))
#print(tr_seqs[:3], tr_dates[:3], tr_labs[:3])
#print(te_seqs[:3], te_dates[:3], te_labs[:3])

#tra_seqs:
##[1, 2, 3],
##[4, 5],
##[6, 7, 7],
##...

#tr_seqs:[[1, 2], [1], [4], [6, 7], [6], ...]
#tr_labs:[3, 2, 5, 7, 7] (為tr_seqs所對應的下一個item_index)
#tr_dates:[session1_date, session1_date, session2_date, session3_date, session3_date, ...]
#tr_ids:[0, 0, 1, 2, 2] ([session1_id, session1_id, session2_id, session3_id, session3_id, ...])
# Out:
# number of training set: 973
# number of testing set: 88

# %%
all = 0
for seq in tra_seqs:
    all += len(seq)
for seq in tes_seqs:
    all += len(seq)
print('avg length of item chain: ', all/(len(tra_seqs) + len(tes_seqs) * 1.0))
# Out:
# avg length of item chain:  3.6004901960784315

# %%
#儲存訓練資料
if not os.path.exists('pickle_dataset'):
    os.makedirs('pickle_dataset')
if not os.path.exists('pickle_dataset/sample'):
    os.makedirs('pickle_dataset/sample')    
pickle.dump(tra, open('pickle_dataset/sample/train.txt', 'wb')) #'wb': write with binary
pickle.dump(tes, open('pickle_dataset/sample/test.txt', 'wb'))
pickle.dump(tra_seqs, open('pickle_dataset/sample/all_train_seq.txt', 'wb'))

print('Done.')
# Out:
# Done.

# %%
opt.dataset
# Out:
# 'sample'
